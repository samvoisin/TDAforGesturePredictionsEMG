# %%
import numpy as np
import scipy.linalg as la
import matplotlib.pyplot as plt

# %%
from scipy.ndimage import gaussian_filter
from sklearn.manifold import Isomap
from sklearn.model_selection import train_test_split
from math import floor

from data_cube import DataCube
from similarity_network_fusion import SNF, cumulated_euc_ts

# %%
dc = DataCube(
    subjects="all",
    gestures=["3", "4", "5", "6"],
    channels=["2", "4", "6", "8"],
    data_grp="parsed")
dc.load_data()
dc.normalize_modalities()
dc.rms_smooth(100, 50)

dc.get_max_obs(smooth=True)

# %%
subj_lab = []
gest_lab = []
arrays = []

for s, gdict in dc.data_set_smooth.items():
    for g, a in gdict.items():
        subj_lab.append(s)
        gest_lab.append(int(g[0]))
        arrays.append(a[:, 1:-1])

# %%
# set to array and base at shift gestures down by 3 (i.e. to 0,1,2,3 instead of 3,4,5,6) for keras
gest_lab = np.array(gest_lab) - 3

# %% [markdown]
# ---

# %%
def cumulated_ts_2(a1, a2):
    """
    cumulated version of the time series w/ euclidean distance
    in which we take the sum values over time as time increases
    and then apply the chosen metric.
    i, j - arrays of data points
    """
    return la.norm(a1.sum(axis=0)-a2.sum(axis=0))

# %% [markdown]
# ---

# %%
# generate raw signal SSMs for each gesture
raw_ssm_lst = [np.zeros(shape=(a.shape[0], a.shape[0])) for a in arrays]
for n, a in enumerate(arrays):
    for i in range(a.shape[0]):
        for j in range(a.shape[0]):
            raw_ssm_lst[n][i,j] = cumulated_ts_2(a[i,:],a[j,:])
                
# smooth SSM images
for r, s in enumerate(raw_ssm_lst):
    raw_ssm_lst[r] = gaussian_filter(s, sigma=1)

# %%
# generate ISOMAP SSMs for each gesture

# initialize embedding
iso = Isomap(n_neighbors=3, n_components=1)

iso_ssm_lst = [np.zeros(shape=(a.shape[0], a.shape[0])) for a in arrays]
for n, a in enumerate(arrays):
    embed = iso.fit_transform(a)
    for i in range(embed.size):
        for j in range(embed.size):
            iso_ssm_lst[n][i,j] = cumulated_ts_2(embed[i,:], embed[j,:])
                
# smooth SSM images
for r, s in enumerate(iso_ssm_lst):
    iso_ssm_lst[r] = gaussian_filter(s, sigma=1)

# %%
# generate SNF images for each gesture

print(len(arrays))

snf_lst = []
for n, a in enumerate(arrays):
    if n % 100 == 0: print(n)
    snf = SNF(a, k=0.2, metric=cumulated_euc_ts)
    # calculate graph weights to find knn
    snf.calc_weights(autotune=False, s=1)
    snf.normalize_weights()
    # generate and normalize knn graphs
    snf.calc_knn_weights(autotune=False, s=1)
    snf.normalize_knn_weights()
    # fuse graphs
    snf.network_fusion(eta=1, iters=20)
    # save template to dict
    snf_lst.append(snf.fused_similarity_template)

# smooth SNF images
for r, s in enumerate(snf_lst):
    snf_lst[r] = gaussian_filter(s, sigma=1)
# Out:
# 576
# 0
# 100
# 200
# 300
# 400
# 500

# %% [markdown]
# ---
# ### Pre-Process images

# %%
# normalize and standardize raw signal SSMs for each gesture
for r, s in enumerate(raw_ssm_lst):
    s = (s-s.mean()) / s.std()

# %%
# normalize and standardize ISOMAP SSMs for each gesture
for r, s in enumerate(iso_ssm_lst):
    s = (s-s.mean()) / s.std()

# %%
# normalize and standardize SNF images for each gesture
for r, s in enumerate(snf_lst):
    s = (s-s.mean()) / s.std()

# %%
# zero pad raw signal SSMs for each gesture
pad_ssm_lst = [np.zeros(shape=(dc.max_obs, dc.max_obs)) for a in arrays]
for r, s in enumerate(raw_ssm_lst):
    pad_ssm_lst[r][:s.shape[0], :s.shape[1]] = s

# %%
# zero pad ISOMAP SSMs for each gesture
pad_iso_lst = [np.zeros(shape=(dc.max_obs, dc.max_obs)) for a in arrays]
for r, s in enumerate(iso_ssm_lst):
    pad_iso_lst[r][:s.shape[0], :s.shape[1]] = s

# %%
# zero pad SNF images for each gesture
pad_snf_lst = [np.zeros(shape=(dc.max_obs, dc.max_obs)) for a in arrays]
for r, s in enumerate(snf_lst):
    pad_snf_lst[r][:s.shape[0], :s.shape[1]] = s

# %% [markdown]
# ---

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical
from keras.optimizers import Adam

np.random.seed(1)
# Out:
# Using TensorFlow backend.
# /home/svois/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/svois/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/svois/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/svois/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/svois/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/svois/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/svois/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/svois/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/svois/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/svois/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/svois/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/svois/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
inp_shp = (dc.max_obs,dc.max_obs,1)

# %%
#Instantiate an empty model
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=32, input_shape=inp_shp, kernel_size=(11,11), strides=(1,1), padding="valid"))
model.add(Activation("relu"))
# Max Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding="valid"))

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(11,11), strides=(1,1), padding="valid"))
model.add(Activation("relu"))
# Max Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding="valid"))

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding="valid"))
model.add(Activation("relu"))

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding="valid"))
model.add(Activation("relu"))

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding="valid"))
model.add(Activation("relu"))
# Max Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding="valid"))

# Passing it to a Fully Connected layer
model.add(Flatten())
# 1st Fully Connected Layer
model.add(Dense(4096, input_shape=(224*224*3,)))
model.add(Activation("relu"))
# Add Dropout to prevent overfitting
model.add(Dropout(0.4))

# 2nd Fully Connected Layer
model.add(Dense(4096))
model.add(Activation("relu"))
# Add Dropout
model.add(Dropout(0.4))

# 3rd Fully Connected Layer
model.add(Dense(1000))
model.add(Activation("relu"))
# Add Dropout
model.add(Dropout(0.4))

# Output Layer
model.add(Dense(4))
model.add(Activation("softmax"))

model.summary()

# %%
# Compile the model
opt = Adam(learning_rate=1e-5, beta_1=0.9, beta_2=0.999, amsgrad=False)

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer="adam",
              metrics=["accuracy"])

# %%
# train/ test
x_train, x_test, y_train, y_test = train_test_split(pad_ssm_lst, gest_lab, test_size=0.2, random_state=1)

# transform to numpy arrays
x_train = np.array(x_train).reshape(len(x_train), 63, 63, 1)
x_test = np.array(x_test).reshape(len(x_test), 63, 63, 1)
y_train = to_categorical(np.array(y_train))
y_test = to_categorical(np.array(y_test))

# %%
batch_size = int(len(gest_lab) / 2)
epochs = 200

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_data=(x_test, y_test),
                    shuffle=True)

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# Flattened to 30-33% around 195 epochs

# %% [markdown]
# ---

# %%
#Instantiate an empty model_iso
model_iso = Sequential()

# 1st Convolutional Layer
model_iso.add(Conv2D(filters=32, input_shape=inp_shp, kernel_size=(11,11), strides=(1,1), padding="valid"))
model_iso.add(Activation("relu"))
# Max Pooling
model_iso.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding="valid"))

# 2nd Convolutional Layer
model_iso.add(Conv2D(filters=256, kernel_size=(11,11), strides=(1,1), padding="valid"))
model_iso.add(Activation("relu"))
# Max Pooling
model_iso.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding="valid"))

# 3rd Convolutional Layer
model_iso.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding="valid"))
model_iso.add(Activation("relu"))

# 4th Convolutional Layer
model_iso.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding="valid"))
model_iso.add(Activation("relu"))

# 5th Convolutional Layer
model_iso.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding="valid"))
model_iso.add(Activation("relu"))
# Max Pooling
model_iso.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding="valid"))

# Passing it to a Fully Connected layer
model_iso.add(Flatten())
# 1st Fully Connected Layer
model_iso.add(Dense(4096, input_shape=(224*224*3,)))
model_iso.add(Activation("relu"))
# Add Dropout to prevent overfitting
model_iso.add(Dropout(0.4))

# 2nd Fully Connected Layer
model_iso.add(Dense(4096))
model_iso.add(Activation("relu"))
# Add Dropout
model_iso.add(Dropout(0.4))

# 3rd Fully Connected Layer
model_iso.add(Dense(1000))
model_iso.add(Activation("relu"))
# Add Dropout
model_iso.add(Dropout(0.4))

# Output Layer
model_iso.add(Dense(4))
model_iso.add(Activation("softmax"))

model_iso.summary()

# %%
# Compile the model
opt = Adam(learning_rate=1e-5, beta_1=0.9, beta_2=0.999, amsgrad=False)

model_iso.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer="adam",
                  metrics=["accuracy"])

# %%
# train/ test
x_train, x_test, y_train, y_test = train_test_split(pad_iso_lst, gest_lab, test_size=0.2, random_state=1)

# transform to numpy arrays
x_train = np.array(x_train).reshape(len(x_train), 63, 63, 1)
x_test = np.array(x_test).reshape(len(x_test), 63, 63, 1)
y_train = to_categorical(np.array(y_train))
y_test = to_categorical(np.array(y_test))

# %%
batch_size = int(len(gest_lab) / 2)
epochs = 200

history = model_iso.fit(x_train, y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        shuffle=True)

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
history.history["val_accuracy"]

# %% [markdown]
# $\approx 35\%$ acc at 200 epochs

# %% [markdown]
# ---

# %%
#Instantiate an empty model_snf
model_snf = Sequential()

# 1st Convolutional Layer
model_snf.add(Conv2D(filters=32, input_shape=inp_shp, kernel_size=(11,11), strides=(1,1), padding="valid"))
model_snf.add(Activation("relu"))
# Max Pooling
model_snf.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding="valid"))

# 2nd Convolutional Layer
model_snf.add(Conv2D(filters=256, kernel_size=(11,11), strides=(1,1), padding="valid"))
model_snf.add(Activation("relu"))
# Max Pooling
model_snf.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding="valid"))

# 3rd Convolutional Layer
model_snf.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding="valid"))
model_snf.add(Activation("relu"))

# 4th Convolutional Layer
model_snf.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding="valid"))
model_snf.add(Activation("relu"))

# 5th Convolutional Layer
model_snf.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding="valid"))
model_snf.add(Activation("relu"))
# Max Pooling
model_snf.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding="valid"))

# Passing it to a Fully Connected layer
model_snf.add(Flatten())
# 1st Fully Connected Layer
model_snf.add(Dense(4096, input_shape=(224*224*3,)))
model_snf.add(Activation("relu"))
# Add Dropout to prevent overfitting
model_snf.add(Dropout(0.4))

# 2nd Fully Connected Layer
model_snf.add(Dense(4096))
model_snf.add(Activation("relu"))
# Add Dropout
model_snf.add(Dropout(0.4))

# 3rd Fully Connected Layer
model_snf.add(Dense(1000))
model_snf.add(Activation("relu"))
# Add Dropout
model_snf.add(Dropout(0.4))

# Output Layer
model_snf.add(Dense(4))
model_snf.add(Activation("softmax"))

model_snf.summary()
# Out:
# WARNING:tensorflow:From /home/svois/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 53, 53, 32)        3904
# _________________________________________________________________
# activation_1 (Activation)    (None, 53, 53, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 26, 26, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 256)       991488
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 256)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 6, 6, 384)         885120
# _________________________________________________________________
# activation_3 (Activation)    (None, 6, 6, 384)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 384)         1327488
# _________________________________________________________________
# activation_4 (Activation)    (None, 4, 4, 384)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 2, 2, 256)         884992
# _________________________________________________________________
# activation_5 (Activation)    (None, 2, 2, 256)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              1052672
# _________________________________________________________________
# activation_6 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# activation_7 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# activation_8 (Activation)    (None, 1000)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 4004
# _________________________________________________________________
# activation_9 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 26,027,980
# Trainable params: 26,027,980
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
opt = Adam(learning_rate=1e-5, beta_1=0.9, beta_2=0.999, amsgrad=False)

model_snf.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer="adam",
                  metrics=["accuracy"])

# %%
# train/ test
x_train, x_test, y_train, y_test = train_test_split(pad_snf_lst, gest_lab, test_size=0.2, random_state=1)

# transform to numpy arrays
x_train = np.array(x_train).reshape(len(x_train), 63, 63, 1)
x_test = np.array(x_test).reshape(len(x_test), 63, 63, 1)
y_train = to_categorical(np.array(y_train))
y_test = to_categorical(np.array(y_test))

# %%
batch_size = int(len(gest_lab) / 2)
epochs = 200

history = model_snf.fit(x_train, y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        shuffle=True)
# Out:
# WARNING:tensorflow:From /home/svois/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 460 samples, validate on 116 samples
# Epoch 1/200
# 460/460 [==============================] - 5s 10ms/step - loss: 2.9358 - accuracy: 0.2870 - val_loss: 1.5534 - val_accuracy: 0.1897
# Epoch 2/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.5085 - accuracy: 0.2370 - val_loss: 1.3930 - val_accuracy: 0.2414
# Epoch 3/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3904 - accuracy: 0.2304 - val_loss: 1.3888 - val_accuracy: 0.2414
# Epoch 4/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3881 - accuracy: 0.2413 - val_loss: 1.3880 - val_accuracy: 0.2414
# Epoch 5/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3868 - accuracy: 0.2826 - val_loss: 1.3881 - val_accuracy: 0.1897
# Epoch 6/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3865 - accuracy: 0.2609 - val_loss: 1.3891 - val_accuracy: 0.1897
# Epoch 7/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3862 - accuracy: 0.2587 - val_loss: 1.3903 - val_accuracy: 0.1897
# Epoch 8/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3861 - accuracy: 0.2522 - val_loss: 1.3911 - val_accuracy: 0.1897
# Epoch 9/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3854 - accuracy: 0.2804 - val_loss: 1.3922 - val_accuracy: 0.1897
# Epoch 10/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3857 - accuracy: 0.2804 - val_loss: 1.3932 - val_accuracy: 0.1897
# Epoch 11/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3860 - accuracy: 0.2761 - val_loss: 1.3948 - val_accuracy: 0.1897
# Epoch 12/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3852 - accuracy: 0.2717 - val_loss: 1.3961 - val_accuracy: 0.1897
# Epoch 13/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3862 - accuracy: 0.2630 - val_loss: 1.3968 - val_accuracy: 0.1897
# Epoch 14/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3869 - accuracy: 0.2674 - val_loss: 1.3966 - val_accuracy: 0.1897
# Epoch 15/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3861 - accuracy: 0.2630 - val_loss: 1.3952 - val_accuracy: 0.1897
# Epoch 16/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3849 - accuracy: 0.2630 - val_loss: 1.3937 - val_accuracy: 0.1897
# Epoch 17/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3855 - accuracy: 0.2609 - val_loss: 1.3928 - val_accuracy: 0.1897
# Epoch 18/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3852 - accuracy: 0.2674 - val_loss: 1.3922 - val_accuracy: 0.1897
# Epoch 19/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3855 - accuracy: 0.2674 - val_loss: 1.3915 - val_accuracy: 0.1897
# Epoch 20/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3852 - accuracy: 0.2652 - val_loss: 1.3911 - val_accuracy: 0.1897
# Epoch 21/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3851 - accuracy: 0.2630 - val_loss: 1.3910 - val_accuracy: 0.1897
# Epoch 22/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3856 - accuracy: 0.2609 - val_loss: 1.3913 - val_accuracy: 0.1897
# Epoch 23/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3857 - accuracy: 0.2630 - val_loss: 1.3917 - val_accuracy: 0.1897
# Epoch 24/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3862 - accuracy: 0.2652 - val_loss: 1.3931 - val_accuracy: 0.1897
# Epoch 25/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3862 - accuracy: 0.2652 - val_loss: 1.3946 - val_accuracy: 0.1897
# Epoch 26/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3859 - accuracy: 0.2652 - val_loss: 1.3962 - val_accuracy: 0.1897
# Epoch 27/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3857 - accuracy: 0.2652 - val_loss: 1.3968 - val_accuracy: 0.1897
# Epoch 28/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3855 - accuracy: 0.2630 - val_loss: 1.3968 - val_accuracy: 0.1897
# Epoch 29/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3848 - accuracy: 0.2674 - val_loss: 1.3967 - val_accuracy: 0.1897
# Epoch 30/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3868 - accuracy: 0.2652 - val_loss: 1.3967 - val_accuracy: 0.1897
# Epoch 31/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3852 - accuracy: 0.2652 - val_loss: 1.3959 - val_accuracy: 0.1897
# Epoch 32/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3855 - accuracy: 0.2587 - val_loss: 1.3957 - val_accuracy: 0.1897
# Epoch 33/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3854 - accuracy: 0.2696 - val_loss: 1.3950 - val_accuracy: 0.1897
# Epoch 34/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3859 - accuracy: 0.2630 - val_loss: 1.3943 - val_accuracy: 0.1897
# Epoch 35/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3854 - accuracy: 0.2674 - val_loss: 1.3942 - val_accuracy: 0.1897
# Epoch 36/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3852 - accuracy: 0.2609 - val_loss: 1.3939 - val_accuracy: 0.1897
# Epoch 37/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3851 - accuracy: 0.2609 - val_loss: 1.3936 - val_accuracy: 0.1897
# Epoch 38/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3856 - accuracy: 0.2587 - val_loss: 1.3933 - val_accuracy: 0.1897
# Epoch 39/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3866 - accuracy: 0.2500 - val_loss: 1.3933 - val_accuracy: 0.1897
# Epoch 40/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3850 - accuracy: 0.2630 - val_loss: 1.3935 - val_accuracy: 0.1897
# Epoch 41/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3844 - accuracy: 0.2674 - val_loss: 1.3937 - val_accuracy: 0.1897
# Epoch 42/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3859 - accuracy: 0.2652 - val_loss: 1.3942 - val_accuracy: 0.1897
# Epoch 43/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3851 - accuracy: 0.2674 - val_loss: 1.3946 - val_accuracy: 0.1897
# Epoch 44/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3860 - accuracy: 0.2630 - val_loss: 1.3947 - val_accuracy: 0.1897
# Epoch 45/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3849 - accuracy: 0.2630 - val_loss: 1.3946 - val_accuracy: 0.1897
# Epoch 46/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3851 - accuracy: 0.2587 - val_loss: 1.3942 - val_accuracy: 0.1897
# Epoch 47/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3856 - accuracy: 0.2674 - val_loss: 1.3939 - val_accuracy: 0.1897
# Epoch 48/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3849 - accuracy: 0.2652 - val_loss: 1.3935 - val_accuracy: 0.1897
# Epoch 49/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3838 - accuracy: 0.2674 - val_loss: 1.3935 - val_accuracy: 0.1897
# Epoch 50/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3852 - accuracy: 0.2630 - val_loss: 1.3938 - val_accuracy: 0.1897
# Epoch 51/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3852 - accuracy: 0.2630 - val_loss: 1.3945 - val_accuracy: 0.1897
# Epoch 52/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3859 - accuracy: 0.2674 - val_loss: 1.3946 - val_accuracy: 0.1897
# Epoch 53/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3848 - accuracy: 0.2783 - val_loss: 1.3945 - val_accuracy: 0.1897
# Epoch 54/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3855 - accuracy: 0.2696 - val_loss: 1.3945 - val_accuracy: 0.1897
# Epoch 55/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3856 - accuracy: 0.2500 - val_loss: 1.3939 - val_accuracy: 0.1897
# Epoch 56/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3848 - accuracy: 0.2717 - val_loss: 1.3943 - val_accuracy: 0.1897
# Epoch 57/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3852 - accuracy: 0.2609 - val_loss: 1.3950 - val_accuracy: 0.1897
# Epoch 58/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3851 - accuracy: 0.2478 - val_loss: 1.3958 - val_accuracy: 0.1897
# Epoch 59/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3851 - accuracy: 0.2674 - val_loss: 1.3964 - val_accuracy: 0.1897
# Epoch 60/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3852 - accuracy: 0.2739 - val_loss: 1.3968 - val_accuracy: 0.1897
# Epoch 61/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3856 - accuracy: 0.2717 - val_loss: 1.3967 - val_accuracy: 0.1897
# Epoch 62/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3858 - accuracy: 0.2543 - val_loss: 1.3957 - val_accuracy: 0.1897
# Epoch 63/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3848 - accuracy: 0.2913 - val_loss: 1.3949 - val_accuracy: 0.1897
# Epoch 64/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3870 - accuracy: 0.2565 - val_loss: 1.3941 - val_accuracy: 0.1897
# Epoch 65/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3838 - accuracy: 0.2761 - val_loss: 1.3936 - val_accuracy: 0.1897
# Epoch 66/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3860 - accuracy: 0.2717 - val_loss: 1.3934 - val_accuracy: 0.1897
# Epoch 67/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3852 - accuracy: 0.2609 - val_loss: 1.3935 - val_accuracy: 0.1897
# Epoch 68/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3868 - accuracy: 0.2565 - val_loss: 1.3935 - val_accuracy: 0.1897
# Epoch 69/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3877 - accuracy: 0.2304 - val_loss: 1.3934 - val_accuracy: 0.1897
# Epoch 70/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3856 - accuracy: 0.2717 - val_loss: 1.3942 - val_accuracy: 0.1897
# Epoch 71/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3862 - accuracy: 0.2717 - val_loss: 1.3948 - val_accuracy: 0.1897
# Epoch 72/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3857 - accuracy: 0.2652 - val_loss: 1.3954 - val_accuracy: 0.1897
# Epoch 73/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3864 - accuracy: 0.2565 - val_loss: 1.3956 - val_accuracy: 0.1897
# Epoch 74/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3861 - accuracy: 0.2674 - val_loss: 1.3951 - val_accuracy: 0.1897
# Epoch 75/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3845 - accuracy: 0.2652 - val_loss: 1.3947 - val_accuracy: 0.1897
# Epoch 76/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3859 - accuracy: 0.2652 - val_loss: 1.3943 - val_accuracy: 0.1897
# Epoch 77/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3866 - accuracy: 0.2674 - val_loss: 1.3942 - val_accuracy: 0.1897
# Epoch 78/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3865 - accuracy: 0.2696 - val_loss: 1.3934 - val_accuracy: 0.1897
# Epoch 79/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3851 - accuracy: 0.2783 - val_loss: 1.3932 - val_accuracy: 0.1897
# Epoch 80/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3860 - accuracy: 0.2804 - val_loss: 1.3931 - val_accuracy: 0.1897
# Epoch 81/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3851 - accuracy: 0.2783 - val_loss: 1.3930 - val_accuracy: 0.1897
# Epoch 82/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3858 - accuracy: 0.2587 - val_loss: 1.3933 - val_accuracy: 0.1897
# Epoch 83/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3853 - accuracy: 0.2609 - val_loss: 1.3935 - val_accuracy: 0.1897
# Epoch 84/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3848 - accuracy: 0.2587 - val_loss: 1.3936 - val_accuracy: 0.1897
# Epoch 85/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3859 - accuracy: 0.2609 - val_loss: 1.3940 - val_accuracy: 0.1897
# Epoch 86/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3865 - accuracy: 0.2652 - val_loss: 1.3939 - val_accuracy: 0.1897
# Epoch 87/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3861 - accuracy: 0.2674 - val_loss: 1.3940 - val_accuracy: 0.1897
# Epoch 88/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3866 - accuracy: 0.2326 - val_loss: 1.3938 - val_accuracy: 0.1897
# Epoch 89/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3861 - accuracy: 0.2630 - val_loss: 1.3938 - val_accuracy: 0.1897
# Epoch 90/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3849 - accuracy: 0.2717 - val_loss: 1.3934 - val_accuracy: 0.1897
# Epoch 91/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3852 - accuracy: 0.2587 - val_loss: 1.3936 - val_accuracy: 0.1897
# Epoch 92/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3856 - accuracy: 0.2630 - val_loss: 1.3938 - val_accuracy: 0.1897
# Epoch 93/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3859 - accuracy: 0.2674 - val_loss: 1.3940 - val_accuracy: 0.1897
# Epoch 94/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3860 - accuracy: 0.2565 - val_loss: 1.3942 - val_accuracy: 0.1897
# Epoch 95/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3861 - accuracy: 0.2739 - val_loss: 1.3940 - val_accuracy: 0.1897
# Epoch 96/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3853 - accuracy: 0.2652 - val_loss: 1.3938 - val_accuracy: 0.1897
# Epoch 97/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3853 - accuracy: 0.2652 - val_loss: 1.3936 - val_accuracy: 0.1897
# Epoch 98/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3844 - accuracy: 0.2674 - val_loss: 1.3936 - val_accuracy: 0.1897
# Epoch 99/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3867 - accuracy: 0.2652 - val_loss: 1.3934 - val_accuracy: 0.1897
# Epoch 100/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3862 - accuracy: 0.2652 - val_loss: 1.3930 - val_accuracy: 0.1897
# Epoch 101/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3850 - accuracy: 0.2652 - val_loss: 1.3930 - val_accuracy: 0.1897
# Epoch 102/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3848 - accuracy: 0.2630 - val_loss: 1.3929 - val_accuracy: 0.1897
# Epoch 103/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3859 - accuracy: 0.2652 - val_loss: 1.3930 - val_accuracy: 0.1897
# Epoch 104/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3857 - accuracy: 0.2674 - val_loss: 1.3932 - val_accuracy: 0.1897
# Epoch 105/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3858 - accuracy: 0.2587 - val_loss: 1.3934 - val_accuracy: 0.1897
# Epoch 106/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3861 - accuracy: 0.2565 - val_loss: 1.3937 - val_accuracy: 0.1897
# Epoch 107/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3853 - accuracy: 0.2696 - val_loss: 1.3937 - val_accuracy: 0.1897
# Epoch 108/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3852 - accuracy: 0.2630 - val_loss: 1.3938 - val_accuracy: 0.1897
# Epoch 109/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3855 - accuracy: 0.2696 - val_loss: 1.3940 - val_accuracy: 0.1897
# Epoch 110/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3864 - accuracy: 0.2652 - val_loss: 1.3941 - val_accuracy: 0.1897
# Epoch 111/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3847 - accuracy: 0.2674 - val_loss: 1.3942 - val_accuracy: 0.1897
# Epoch 112/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3859 - accuracy: 0.2652 - val_loss: 1.3944 - val_accuracy: 0.1897
# Epoch 113/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3865 - accuracy: 0.2674 - val_loss: 1.3945 - val_accuracy: 0.1897
# Epoch 114/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3857 - accuracy: 0.2609 - val_loss: 1.3944 - val_accuracy: 0.1897
# Epoch 115/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3859 - accuracy: 0.2609 - val_loss: 1.3943 - val_accuracy: 0.1897
# Epoch 116/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3860 - accuracy: 0.2609 - val_loss: 1.3944 - val_accuracy: 0.1897
# Epoch 117/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3855 - accuracy: 0.2630 - val_loss: 1.3946 - val_accuracy: 0.1897
# Epoch 118/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3867 - accuracy: 0.2630 - val_loss: 1.3947 - val_accuracy: 0.1897
# Epoch 119/200
# 460/460 [==============================] - 4s 10ms/step - loss: 1.3855 - accuracy: 0.2652 - val_loss: 1.3946 - val_accuracy: 0.1897
# Epoch 120/200
# 288/460 [=================>............] - ETA: 1s - loss: 1.3863 - accuracy: 0.2361

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# Got into 32% around 200 epochs

# %%
history.history["val_accuracy"]
