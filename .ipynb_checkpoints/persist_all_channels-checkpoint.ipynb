# %% [markdown]
# https://persim.scikit-tda.org/notebooks/Persistence%20Images.html

# %%
import numpy as np
from ripser import ripser
from persim import plot_diagrams
from persim import wasserstein, wasserstein_matching
from persim import bottleneck, bottleneck_matching

import matplotlib.pyplot as plt

from TDA_helper_fcns import load_data, sublevel_set_time_series_dist

# %%
gdat = load_data(subjects=["02", "09", "30"]) # gestures data

## code below taken from gen_all_pds.py - look there for os cmds and saving
# iterate through all subjects
pd_dict = dict()

for sbj, sdict in gdat.items():
    # Dictionary of each subject with all gestures
    for gnum, garray in sdict.items():
        # loop through each signal in the gesture
        t_axis = garray[:, 0] # time data
        for s in range(1, garray.shape[1]-1):
            # sublevel set filtraton
            sls = sublevel_set_time_series_dist(garray[:,s])
            # generate persistence diagram
            pd = ripser(sls, distance_matrix=True)
            # remove inf persistence point
            pd["dgms"][0] = pd["dgms"][0][np.isfinite(pd["dgms"][0][:,1]),:]
            pd_dict[sbj+"_"+gnum+"_"+str(s)] = pd # FIX FOR ONLY LOOKING AT ONE CHANNEL IS HERE

# %%
from ripser import Rips
from persim import PersImage

# %%
# subject 2 gesture 3
all_chan = gdat["02"]['3_0_2'][:, 1:-1] # channels w/ no time or label
all_chan
# Out:
# array([[ 3.0e-04,  7.0e-05,  1.0e-05, ...,  1.9e-04, -4.3e-04,  1.1e-04],
#        [ 1.1e-03,  2.2e-04,  5.0e-05, ...,  2.2e-04,  1.9e-04,  2.9e-04],
#        [ 1.1e-03,  2.2e-04,  5.0e-05, ...,  2.2e-04,  1.9e-04,  2.9e-04],
#        ...,
#        [ 1.0e-05, -2.0e-05, -1.0e-05, ..., -8.0e-05, -7.3e-04, -2.1e-04],
#        [ 1.0e-05, -2.0e-05, -1.0e-05, ..., -8.0e-05, -7.3e-04, -2.1e-04],
#        [ 1.0e-05, -2.0e-05, -1.0e-05, ..., -8.0e-05, -7.3e-04, -2.1e-04]])

# %%
rips = Rips(maxdim=1, verbose=True) # 2 persistence too expensive
dgms = rips.fit_transform(all_chan)
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)

# %%
rips.plot(dgms, legend=True, show=False)

# %%
sprd1 = 1e-5
sprd2 = 1e-5
sprd3 = 1e-5


pim = PersImage(spread=sprd1, pixels=[10,10], verbose=False)
img = pim.transform(dgms[1])

ax = plt.subplot(131)
plt.title("PI for $H_1$\nwith 10x10 pixels")
pim.show(img, ax)

pim = PersImage(spread=sprd2, pixels=[20,20], verbose=False)
img = pim.transform(dgms[1])

ax = plt.subplot(132)
plt.title("PI for $H_1$\nwith 20x20 pixels")
pim.show(img, ax)

pim = PersImage(spread=sprd3, pixels=[50,50], verbose=False)
img = pim.transform(dgms[1])

ax = plt.subplot(133)
plt.title("PI for $H_1$\nwith 50x50 pixels")
pim.show(img, ax)

plt.tight_layout()

# %%
# subject 9 gesture 3
all_chan = gdat["09"]['3_0_2'][:, 1:-1] # channels w/ no time or label
rips = Rips(maxdim=1, verbose=True) # 2 persistence too expensive
dgms = rips.fit_transform(all_chan)
rips.plot(dgms, legend=True, show=False)
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)

# %%
sprd1 = 1e-5
sprd2 = 1e-5
sprd3 = 1e-5


pim = PersImage(spread=sprd1, pixels=[10,10], verbose=False)
img = pim.transform(dgms[1])

ax = plt.subplot(131)
plt.title("PI for $H_1$\nwith 10x10 pixels")
pim.show(img, ax)

pim = PersImage(spread=sprd2, pixels=[20,20], verbose=False)
img = pim.transform(dgms[1])

ax = plt.subplot(132)
plt.title("PI for $H_1$\nwith 20x20 pixels")
pim.show(img, ax)

pim = PersImage(spread=sprd3, pixels=[50,50], verbose=False)
img = pim.transform(dgms[1])

ax = plt.subplot(133)
plt.title("PI for $H_1$\nwith 50x50 pixels")
pim.show(img, ax)

plt.tight_layout()

# %%
# subject 2 gesture 2
all_chan = gdat["02"]['2_0_2'][:, 1:-1] # channels w/ no time or label
rips = Rips(maxdim=1, verbose=True) # 2 persistence too expensive
dgms = rips.fit_transform(all_chan)
rips.plot(dgms, legend=True, show=False)
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)

# %%
sprd1 = 1e-5
sprd2 = 1e-5
sprd3 = 1e-5


pim = PersImage(spread=sprd1, pixels=[10,10], verbose=False)
img = pim.transform(dgms[1])

ax = plt.subplot(131)
plt.title("PI for $H_1$\nwith 10x10 pixels")
pim.show(img, ax)

pim = PersImage(spread=sprd2, pixels=[20,20], verbose=False)
img = pim.transform(dgms[1])

ax = plt.subplot(132)
plt.title("PI for $H_1$\nwith 20x20 pixels")
pim.show(img, ax)

pim = PersImage(spread=sprd3, pixels=[50,50], verbose=False)
img = pim.transform(dgms[1])

ax = plt.subplot(133)
plt.title("PI for $H_1$\nwith 50x50 pixels")
pim.show(img, ax)

plt.tight_layout()

# %%
# subject 9 gesture 2
all_chan = gdat["09"]['2_0_2'][:, 1:-1] # channels w/ no time or label
rips = Rips(maxdim=1, verbose=True) # 2 persistence too expensive
dgms = rips.fit_transform(all_chan)
rips.plot(dgms, legend=True, show=False)
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)

# %%
sprd1 = 1e-5
sprd2 = 1e-5
sprd3 = 1e-5


pim = PersImage(spread=sprd1, pixels=[10,10], verbose=False)
img = pim.transform(dgms[1])

ax = plt.subplot(131)
plt.title("PI for $H_1$\nwith 10x10 pixels")
pim.show(img, ax)

pim = PersImage(spread=sprd2, pixels=[20,20], verbose=False)
img = pim.transform(dgms[1])

ax = plt.subplot(132)
plt.title("PI for $H_1$\nwith 20x20 pixels")
pim.show(img, ax)

pim = PersImage(spread=sprd3, pixels=[50,50], verbose=False)
img = pim.transform(dgms[1])

ax = plt.subplot(133)
plt.title("PI for $H_1$\nwith 50x50 pixels")
pim.show(img, ax)

plt.tight_layout()
