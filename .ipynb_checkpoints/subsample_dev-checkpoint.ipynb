# %%
import numpy as np
from data_cube import DataCube

# %%
def grow_array(a, axis=0):
    """
    Increase size of array by doubling on specified axis
    doubling this way gives O(log n) amortized time
    
    INPUTS
    a - input array of type np.array; must be 2 dimensional
    axis - is axis on which to double
    """
    r, c = a.shape
    blnk = np.zeros(shape=(r,c)) # blank array
    if axis == 0:
        res = np.r_[a, blnk]
        return res
    else:
        res = np.c_[a, blnk]
        return res
    
def trim_array(a, axis=0):
    """
    Trim zero rows from the bottom of an array
    
    INPUTS
    a - input array of type np.array; must be 2 dimensional
    axis - is axis on which to double
    """
    r, c = a.shape
    for n, i in enumerate(a):
        if all(i == np.zeros(c)):
            return a[:n, :]
        else:
            return a

# %%
dc = DataCube(
        subjects=["10", "20", "22"],
        gestures=["1", "2", "3", "4"],
        channels=["2", "4", "5", "6", "8"],
        data_grp="parsed"
        )
dc.load_data()

# %%
dc.plot_gests("22", "1_1_2")

# %%
tst=dc.data_set["22"]["1_1_2"]
tst.shape
# Out:
# (1354, 7)

# %%
sf = tst[0, :].reshape(1, -1)
c = 0
for n, r in enumerate(tst):
    
    if all(sf[c, 1:] == r[1:]):
        continue
    else:
        c += 1
        if sf.shape[0] <= c:
            sf = grow_array(sf)
        sf[c, :] = r

# %%
sf = trim_array(sf)

# %%
sf.shape
# Out:
# (128, 7)

# %%
dc.data_set["10"]["2_0_2"] = sf

# %%
dc.plot_gests("10", "2_0_2")

# %% [markdown]
# ---

# %%
dc2 = DataCube(
        subjects=["10", "20"],
        data_grp="subsample"
        )
dc2.load_data()

# %%
dc2.data_set["10"]["2_0_2"].shape

# %%
dc2.plot_gests("10", "2_0_2")
