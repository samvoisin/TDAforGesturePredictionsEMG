# %%
import numpy as np
from numpy import linalg as la
import matplotlib.pyplot as plt
from scipy.interpolate import griddata

from data_cube import DataCube
from ssm import SSM
from snf import SNF

# %%
dc = DataCube(
    subjects=["01"],
    gestures=["1", "2", "3", "4"],
    channels=["2", "4", "5", "6", "8"],
    data_grp="parsed"
)
dc.load_data()
dc.rms_smooth(300, 20)
dc.get_max_obs(smooth=True)

# %%
snf_tst = SNF(dc.data_set_smooth["01"]["1_0_1"][:, :6])
snf_tst.normalize_modalities()

# %%
snf_tst.calc_SSM()

# %%
# channel 2
snf_tst.plot_SSM(0)

# %%
# channel 4
snf_tst.plot_SSM(1)

# %%
# channel 5
snf_tst.plot_SSM(2)

# %%
# channel 6
snf_tst.plot_SSM(3)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-7e31369303d4> in <module>
#       1 # channel 6
# ----> 2 snf_tst.plot_SSM(3)
#
# ~/DukeUniv/MATH713_Topological_Data_Analysis/TDAforGesturePredictionsEMG/ssm.py in plot_SSM(self, m, interp, cmap, figsize, save, path)
#     107         plt.figure(figsize=figsize)
#     108         plt.subplot(121)
# --> 109         plt.plot(self.tidx, self.mods[:, m])
#     110         plt.title("Modality " + str(m))
#     111         plt.subplot(122)
#
# IndexError: index 3 is out of bounds for axis 1 with size 3

# %%
# channel 8
snf_tst.plot_SSM(4)

# %%
snf_tst.calc_sim_matrix()

# %%
# channel 2
snf_tst.plot_SSM(0)

# %%
# channel 4
snf_tst.plot_SSM(1)

# %%
# channel 5
snf_tst.plot_SSM(2)

# %%
# channel 6
snf_tst.plot_SSM(3)

# %%
# channel 8
snf_tst.plot_SSM(4)

# %%
snf_tst.calc_transition_matrix()
snf_tst.calc_similarity_graph(0.1)

# %%
snf_tst.network_fusion()

# %%
snf_tst.plot_template(0, fused=False)

# %%
snf_tst.plot_template(1, fused=False)

# %%
snf_tst.plot_template(2, fused=False)

# %%
snf_tst.plot_template(3, fused=False)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-38a39ce49ec9> in <module>
# ----> 1 snf_tst.plot_template(3, fused=False)
#
# ~/DukeUniv/MATH713_Topological_Data_Analysis/TDAforGesturePredictionsEMG/snf.py in plot_template(self, m, fused, interp, cmap, figsize, save, path)
#     127         else:
#     128             plt.imshow(
# --> 129                 self.similarity_templates[m, :, :],
#     130                 interpolation=interp,
#     131                 cmap=cmap)
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %%
snf_tst.plot_template(4, fused=False)

# %%
snf_tst.plot_template()

# %%
tidx = snf_tst.tidx
mods = snf_tst.mods

# %%
plt.plot(tidx, mods[:,0])
plt.plot(tidx, mods[:,1])
plt.plot(tidx, mods[:,2])
#plt.plot(tidx, mods[:,3])
#plt.plot(tidx, mods[:,4])
plt.show()
