# %%
import numpy as np
from numpy import linalg as la
import matplotlib.pyplot as plt
from scipy.interpolate import griddata

from data_cube import DataCube
from ssm import SSM

# %%
dc = DataCube(
    subjects=["01"],
    gestures=["1", "2", "3", "4"],
    channels=["2", "4", "5", "6", "8"],
    data_grp="parsed"
)
dc.load_data()
dc.rms_smooth(300, 50)
dc.get_max_obs(smooth=True)

# %%
dc.max_obs
# Out:
# 37

# %%
# define a metric
ed = lambda i, j: abs(i-j)

# %%
s1g101 = SSM(dc.data_set_smooth["01"]["1_0_1"][:, :2], metric=ed) # exclude label col
s1g101.normalize_modalities()
s1g101.calc_SSM()
s1g101.plot_SSM(0)

# %%
s1g111 = SSM(dc.data_set_smooth["01"]["1_1_1"][:, :2], metric=ed) # exclude label col
s1g111.normalize_modalities()
s1g111.calc_SSM()
s1g111.plot_SSM(0)

# %%
s1g101.to_sim_measure()
s1g101.plot_SSM(0)

# %%
s1g111.to_sim_measure()
s1g111.plot_SSM(0)

# %% [markdown]
# ---

# %%
from snf import SNF

# %%
t = SNF(dc.data_set_smooth["01"]["1_1_1"][:, :2])

# %%
t.array.shape
# Out:
# (1, 28, 28)

# %%
t.calc_SSM()

# %%
t.plot_SSM(0)

# %%
t.normalize_modalities()
t.calc_sim_matrix()

# %%
t.plot_SSM(0)
