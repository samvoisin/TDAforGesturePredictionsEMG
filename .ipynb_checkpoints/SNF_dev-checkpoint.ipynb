# %%
import numpy as np
from numpy import linalg as la
import matplotlib.pyplot as plt
from scipy.interpolate import griddata

from data_cube import DataCube
from ssm import SSM

# %%
dc = DataCube(
    subjects="all",
    gestures=["1", "2", "3", "4"],
    channels=["2", "4", "5", "6", "8"],
    data_grp="parsed"
)
dc.load_data()
dc.rms_smooth(300, 50)
dc.get_max_obs(smooth=True)

# %%
dc.max_obs
# Out:
# 80

# %%
# define a metric
ed = lambda i, j: (i-j)**2

# %%
# ?griddata

# %%
s1g101 = SSM(dc.data_set_smooth["01"]["1_0_1"][:, :2], metric=ed) # exclude label col
s1g101.normalize_SSM()
s1g101.calc_SSM()
s1g101.plot_SSM(0)

# %%
s1g111 = SSM(dc.data_set_smooth["01"]["1_1_1"][:, :2], metric=ed) # exclude label col
s1g111.normalize_SSM()
s1g111.calc_SSM()
s1g111.plot_SSM(0)

# %% [markdown]
# I want to interpolate `s1g111` to the size of `s1g101`.
