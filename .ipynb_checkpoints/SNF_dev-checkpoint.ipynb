# %%
import numpy as np
from numpy import linalg as la
import matplotlib.pyplot as plt
from scipy.interpolate import griddata

from data_cube import DataCube
from ssm import SSM

# %%
dc = DataCube(
    subjects=["01"],
    gestures=["1", "2", "3", "4"],
    channels=["2", "4", "5", "6", "8"],
    data_grp="parsed"
)
dc.load_data()
dc.rms_smooth(300, 20)
dc.get_max_obs(smooth=True)

# %% [markdown]
# s1g101 = SSM(dc.data_set_smooth["01"]["1_0_1"][:, :2]) # exclude label col
# s1g101.normalize_modalities()
# s1g101.calc_SSM()
# s1g101.plot_SSM(0)

# %% [markdown]
# s1g111 = SSM(dc.data_set_smooth["01"]["1_1_1"][:, :2]) # exclude label col
# s1g111.normalize_modalities()
# s1g111.calc_SSM()
# s1g111.plot_SSM(0)

# %% [markdown]
# s1g101.calc_sim_matrix()
# s1g101.plot_SSM(0)

# %% [markdown]
# s1g111.calc_sim_matrix()
# s1g111.plot_SSM(0)

# %% [markdown]
# ---
#
# ### Using `SNF` Class

# %%
from snf import SNF

# %%
snf_tst = SNF(dc.data_set_smooth["01"]["2_1_1"][:, :6])
snf_tst.normalize_modalities()

# %%
snf_tst.calc_SSM()

# %%
# channel 2
snf_tst.plot_SSM(0)

# %%
# channel 4
snf_tst.plot_SSM(1)

# %%
# channel 5
snf_tst.plot_SSM(2)

# %%
# channel 6
snf_tst.plot_SSM(3)

# %%
# channel 8
snf_tst.plot_SSM(4)

# %%
snf_tst.calc_sim_matrix()

# %%
# channel 2
snf_tst.plot_SSM(0)

# %%
# channel 4
snf_tst.plot_SSM(1)

# %%
# channel 5
snf_tst.plot_SSM(2)

# %%
# channel 6
snf_tst.plot_SSM(3)

# %%
# channel 8
snf_tst.plot_SSM(4)

# %%
snf_tst.calc_transition_matrix()
snf_tst.calc_masked_transition_matrix(8)

# %%
def tensor_sum_except(tensor, n):
    """
    sum all matrices in a tensor excluding matrix `n`
    """
    return tensor.sum(axis=0) - tensor[n,:,:]

# %%
for i in range(20):
    for m in range(snf_tst.n_mods):
        snf_tst.trans_mtrx[m,:,:] = (
            snf_tst.masked_mtrx[m,:,:] @
            (tensor_sum_except(snf_tst.trans_mtrx, m)/(snf_tst.n_mods-1)) @
            snf_tst.masked_mtrx[m,:,:].T
        )

# %%
snf_tst.plot_template(0)

# %%
snf_tst.plot_template(1)

# %%
snf_tst.plot_template(2)

# %%
snf_tst.plot_template(3)

# %%
snf_tst.plot_template(4)

# %%
fuse_tmp = snf_tst.trans_mtrx.sum(axis=0)

# %%
plt.imshow(fuse_tmp,interpolation='nearest',cmap='afmhot')
plt.show()
