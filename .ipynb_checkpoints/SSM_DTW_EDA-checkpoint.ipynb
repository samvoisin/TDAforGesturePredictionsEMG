# %%
import numpy as np

from data_cube import DataCube
from ssm import SSM

import matplotlib.pyplot as plt

# %%
dc = DataCube(
    subjects="all",
    gestures=["1", "2", "3", "4"],
    data_grp="parsed"
)
dc.load_data()

# %%
dc.rms_smooth(300, 50)

# %%
ed = lambda i, j: (i-j)**2
s1g101 = SSM(dc.data_set_smooth["01"]["1_0_1"][:, :2], metric=ed) # exclude label col
s1g101.normalize_SSM()
s1g101.calc_SSM()

# %%
s1g101.plot_SSM(0)

# %%
s1g111 = SSM(dc.data_set_smooth["01"]["1_1_1"][:, :2], metric=ed) # exclude label col
s1g111.normalize_SSM()
s1g111.calc_SSM()

# %%
s1g111.plot_SSM(0)

# %%
s1g112 = SSM(dc.data_set_smooth["01"]["1_1_2"][:, :2], metric=ed) # exclude label col
s1g112.normalize_SSM()
s1g112.calc_SSM()

# %%
s1g112.plot_SSM(0)

# %%
s2g101 = SSM(dc.data_set_smooth["02"]["1_0_1"][:, :2], metric=ed) # exclude label col
s2g101.normalize_SSM()
s2g101.calc_SSM()

# %%
s2g101.plot_SSM(0)

# %%
s2g102 = SSM(dc.data_set_smooth["02"]["1_0_2"][:, :2], metric=ed) # exclude label col
s2g102.normalize_SSM()
s2g102.calc_SSM()

# %%
s2g102.plot_SSM(0)

# %% [markdown]
# ---

# %% [markdown]
# ### TS Learn

# %%
from tslearn.generators import random_walks
from tslearn.preprocessing import TimeSeriesScalerMeanVariance
from tslearn import metrics

# %%
ts1  = dc.data_set_smooth["10"]["1_1_1"][:, 0].astype(np.int32)
ts2 = dc.data_set_smooth["10"]["1_0_1"][:, 0].astype(np.int32)
t1 = dc.data_set_smooth["10"]["1_1_1"][:, 1]
t2 = dc.data_set_smooth["10"]["1_0_1"][:, 2]

# %%
#plt.figure()
plt.subplot(211)
plt.plot(ts1, t1)
plt.subplot(212)
plt.plot(ts2, t2)
plt.show()

# %%
np.random.seed(0)
n_ts, sz, d = 2, 100, 1
dataset = random_walks(n_ts=n_ts, sz=sz, d=d)

scaler = TimeSeriesScalerMeanVariance(mu=0., std=1.)  # Rescale time series
dataset_scaled = scaler.fit_transform(dataset)

path, sim = metrics.dtw_path(t1, t2)

# %%
matrix_path = np.zeros((ts1.size, ts2.size), dtype=np.int)
for i, j in path:
    matrix_path[i, j] = 1

# %%
plt.imshow(matrix_path)
plt.show()

# %%
plt.figure()

plt.subplot2grid((1, 3), (0, 0), colspan=2)
plt.plot(ts1, t1)
plt.plot(ts2, t2)
#plt.subplot(1, 3, 3)
#plt.imshow(matrix_path, cmap="gray_r")

plt.tight_layout()
plt.show()

# %%
sim
# Out:
# 3.8649533851848655e-05
