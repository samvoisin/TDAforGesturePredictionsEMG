# %%
import numpy as np
import persim
from numpy import linalg as la
import matplotlib.pyplot as plt

from data_cube import DataCube
from ssm import SSM
from similarity_network_fusion import cumulated_euc_ts
from ripser import lower_star_img
from persim import plot_diagrams, PersImage, bottleneck
from scipy.ndimage import gaussian_filter

# %%
dc = DataCube(
    subjects=["10", "20"],
    gestures=["3","4"],
    channels=["2", "4", "6", "8"],
    data_grp="parsed"
)
dc.load_data()
dc.normalize_modalities()
dc.rms_smooth(100, 20)

# %%
def cumulated_euc_ts(a1, a2):
    """
    cumulated version of the time series w/ euclidean distance
    in which we take the sum values over time as time increases
    and then apply the chosen metric.
    i, j - arrays of data points
    """
    return la.norm(a1.sum(axis=0)-a2.sum(axis=0))

# %%
subj_lab = []
gest_lab = []
arrays = []

for s, gdict in dc.data_set_smooth.items():
        for g, a in gdict.items():
            subj_lab.append(s)
            gest_lab.append(int(g[0]))
            arrays.append(a[:, 1:-1])

# %%
raw_ssm_lst = [np.zeros(shape=(a.shape[0], a.shape[0])) for a in arrays]
for n, a in enumerate(arrays):
    for i in range(a.shape[0]):
        for j in range(a.shape[0]):
            raw_ssm_lst[n][i,j] = cumulated_euc_ts(a[i,:],a[j,:])

# %%
for r, s in enumerate(raw_ssm_lst):
    raw_ssm_lst[r] = gaussian_filter(s, sigma=1)

# %%
lwr_star_lst = []
for r, s in enumerate(raw_ssm_lst):
    lwr_star_lst.append(lower_star_img(s))
# Out:
# /home/svois/anaconda3/lib/python3.6/site-packages/ripser/ripser.py:342: RuntimeWarning: invalid value encountered in maximum
#   thisD = np.maximum(thisD, tD)

# %%
for i in lwr_star_lst:
    plot_diagrams(i)
    plt.show()

# %%
from persim import wasserstein

# %%
predicts = []
for n, g1 in enumerate(lwr_star_lst):
    g1_dtws = []
    for m, g2 in enumerate(lwr_star_lst):
        g1_dtws.append(bottleneck(g1, g2, matching=False))
    g1_dtws = np.array(g1_dtws)
    pred_idx = np.argsort(g1_dtws)[1] # index of 2nd closest array by dtw; 1st closest is self
    predicts.append(gest_lab[pred_idx])

acc = (sum(np.array(gest_lab) == np.array(predicts)) / len(gest_lab)) * 100

print(f"accuracy: {acc}%")
# Out:
# accuracy: 43.75%

# %%
predicts
# Out:
# [3, 3, 4, 3, 4, 4, 4, 4, 4, 4, 3, 3, 3, 4, 3, 4]

# %%
# wasserstein
predicts = []
for n, g1 in enumerate(lwr_star_lst):
    g1_dtws = []
    for m, g2 in enumerate(lwr_star_lst):
        g1_dtws.append(wasserstein(g1, g2, matching=False))
    g1_dtws = np.array(g1_dtws)
    pred_idx = np.argsort(g1_dtws)[1] # index of 2nd closest array by dtw; 1st closest is self
    predicts.append(gest_lab[pred_idx])

acc = (sum(np.array(gest_lab) == np.array(predicts)) / len(gest_lab)) * 100

print(f"accuracy: {acc}%")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-1c1815517f81> in <module>
#       4     g1_dtws = []
#       5     for m, g2 in enumerate(lwr_star_lst):
# ----> 6         g1_dtws.append(wasserstein(g1, g2, matching=False))
#       7     g1_dtws = np.array(g1_dtws)
#       8     pred_idx = np.argsort(g1_dtws)[1] # index of 2nd closest array by dtw; 1st closest is self
#
# ~/anaconda3/lib/python3.6/site-packages/persim/wasserstein.py in wasserstein(dgm1, dgm2, matching)
#      45         dgm2 = np.array([[0, 0]])
#      46         M = 1
# ---> 47     DUL = metrics.pairwise.pairwise_distances(dgm1, dgm2)
#      48
#      49     # Put diagonal elements into the matrix
#
# ~/.local/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in pairwise_distances(X, Y, metric, n_jobs, **kwds)
#    1404         func = partial(distance.cdist, metric=metric, **kwds)
#    1405
# -> 1406     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1407
#    1408
#
# ~/.local/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1065
#    1066     if effective_n_jobs(n_jobs) == 1:
# -> 1067         return func(X, Y, **kwds)
#    1068
#    1069     # TODO: in some cases, backend='threading' may be appropriate
#
# ~/.local/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     222     paired_distances : distances betweens pairs of elements of X and Y.
#     223     """
# --> 224     X, Y = check_pairwise_arrays(X, Y)
#     225
#     226     if X_norm_squared is not None:
#
# ~/.local/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in check_pairwise_arrays(X, Y, precomputed, dtype)
#     106     if Y is X or Y is None:
#     107         X = Y = check_array(X, accept_sparse='csr', dtype=dtype,
# --> 108                             warn_on_dtype=warn_on_dtype, estimator=estimator)
#     109     else:
#     110         X = check_array(X, accept_sparse='csr', dtype=dtype,
#
# ~/.local/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     571         if force_all_finite:
#     572             _assert_all_finite(array,
# --> 573                                allow_nan=force_all_finite == 'allow-nan')
#     574
#     575     shape_repr = _shape_repr(array.shape)
#
# ~/.local/lib/python3.6/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57
#      58
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
