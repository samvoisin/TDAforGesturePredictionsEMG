# %%
import numpy as np
import scipy.linalg as la
import matplotlib.pyplot as plt

# %%
from scipy.ndimage import gaussian_filter
from sklearn.manifold import Isomap
from sklearn.model_selection import train_test_split
from math import floor

from data_cube import DataCube
from similarity_network_fusion import SNF, cumulated_euc_ts

# %%
dc = DataCube(
    subjects="all",
    gestures=["3", "4", "5", "6"],
    channels=["2", "4", "6", "8"],
    data_grp="parsed")
dc.load_data()
dc.normalize_modalities()
dc.rms_smooth(100, 50)

dc.get_max_obs(smooth=True)

# %%
subj_lab = []
gest_lab = []
arrays = []

for s, gdict in dc.data_set_smooth.items():
    for g, a in gdict.items():
        subj_lab.append(s)
        gest_lab.append(int(g[0]))
        arrays.append(a[:, 1:-1])

# %%
# set to array and base at shift gestures down by 3 (i.e. to 0,1,2,3 instead of 3,4,5,6) for keras
gest_lab = np.array(gest_lab) - 3

# %% [markdown]
# ---

# %%
def cumulated_ts_2(a1, a2):
    """
    cumulated version of the time series w/ euclidean distance
    in which we take the sum values over time as time increases
    and then apply the chosen metric.
    i, j - arrays of data points
    """
    return la.norm(a1.sum(axis=0)-a2.sum(axis=0))

# %% [markdown]
# ---

# %%
# generate raw signal SSMs for each gesture
raw_ssm_lst = [np.zeros(shape=(a.shape[0], a.shape[0])) for a in arrays]
for n, a in enumerate(arrays):
    for i in range(a.shape[0]):
        for j in range(a.shape[0]):
            raw_ssm_lst[n][i,j] = cumulated_ts_2(a[i,:],a[j,:])
                
# smooth SSM images
for r, s in enumerate(raw_ssm_lst):
    raw_ssm_lst[r] = gaussian_filter(s, sigma=1)

# %%
# generate ISOMAP SSMs for each gesture

# initialize embedding
iso = Isomap(n_neighbors=3, n_components=1)

iso_ssm_lst = [np.zeros(shape=(a.shape[0], a.shape[0])) for a in arrays]
for n, a in enumerate(arrays):
    embed = iso.fit_transform(a)
    for i in range(embed.size):
        for j in range(embed.size):
            iso_ssm_lst[n][i,j] = cumulated_ts_2(embed[i,:], embed[j,:])
                
# smooth SSM images
for r, s in enumerate(iso_ssm_lst):
    iso_ssm_lst[r] = gaussian_filter(s, sigma=1)

# %%
# generate SNF images for each gesture

print(len(arrays))

snf_lst = []
for n, a in enumerate(arrays):
    if n % 100 == 0: print(n)
    snf = SNF(a, k=0.2, metric=cumulated_euc_ts)
    # calculate graph weights to find knn
    snf.calc_weights()
    snf.normalize_weights()
    # generate and normalize knn graphs
    snf.calc_knn_weights()
    snf.normalize_knn_weights()
    # fuse graphs
    snf.network_fusion(eta=1, iters=20)
    # save template to dict
    snf_lst.append(snf.fused_similarity_template)

# smooth SNF images
for r, s in enumerate(snf_lst):
    snf_lst[r] = gaussian_filter(s, sigma=1)
# Out:
# 576
# 0
# 100
# 200
# 300
# 400
# 500

# %% [markdown]
# ---
# ### Pre-Process images

# %%
# normalize and standardize raw signal SSMs for each gesture
for r, s in enumerate(raw_ssm_lst):
    s = (s-s.mean()) / s.std()

# %%
# normalize and standardize ISOMAP SSMs for each gesture
for r, s in enumerate(iso_ssm_lst):
    s = (s-s.mean()) / s.std()

# %%
# normalize and standardize SNF images for each gesture
for r, s in enumerate(snf_lst):
    s = (s-s.mean()) / s.std()

# %%
# zero pad raw signal SSMs for each gesture
pad_ssm_lst = [np.zeros(shape=(dc.max_obs, dc.max_obs)) for a in arrays]
for r, s in enumerate(raw_ssm_lst):
    pad_ssm_lst[r][:s.shape[0], :s.shape[1]] = s

# %%
# zero pad ISOMAP SSMs for each gesture
pad_iso_lst = [np.zeros(shape=(dc.max_obs, dc.max_obs)) for a in arrays]
for r, s in enumerate(iso_ssm_lst):
    pad_iso_lst[r][:s.shape[0], :s.shape[1]] = s

# %%
# zero pad SNF images for each gesture
pad_snf_lst = [np.zeros(shape=(dc.max_obs, dc.max_obs)) for a in arrays]
for r, s in enumerate(snf_lst):
    pad_snf_lst[r][:s.shape[0], :s.shape[1]] = s

# %% [markdown]
# ---

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical
from keras.optimizers import Adam
from keras import regularizers

np.random.seed(1)
# Out:
# Using TensorFlow backend.
# /home/svois/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/svois/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/svois/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/svois/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/svois/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/svois/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/svois/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/svois/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/svois/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/svois/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/svois/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/svois/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
inp_shp = (dc.max_obs,dc.max_obs,1)

# %%
#Instantiate an empty model
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=inp_shp, kernel_size=(11,11), strides=(1,1), padding="valid"))
model.add(Activation("relu"))
# Max Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding="valid"))

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(11,11), strides=(1,1), padding="valid"))
model.add(Activation("relu"))
# Max Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding="valid"))

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding="valid"))
model.add(Activation("relu"))

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding="valid"))
model.add(Activation("relu"))

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding="valid"))
model.add(Activation("relu"))
# Max Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding="valid"))

# Passing it to a Fully Connected layer
model.add(Flatten())
# 1st Fully Connected Layer
model.add(Dense(4096, input_shape=(224*224*3,)))
model.add(Activation("relu"))
# Add Dropout to prevent overfitting
model.add(Dropout(0.4))

# 2nd Fully Connected Layer
model.add(Dense(4096))
model.add(Activation("relu"))
# Add Dropout
model.add(Dropout(0.4))

# 3rd Fully Connected Layer
model.add(Dense(1000))
model.add(Activation("relu"))
# Add Dropout
model.add(Dropout(0.4))

# Output Layer
model.add(Dense(4))
model.add(Activation("softmax"))

model.summary()
# Out:
# WARNING:tensorflow:From /home/svois/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 53, 53, 96)        11712
# _________________________________________________________________
# activation_1 (Activation)    (None, 53, 53, 96)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 26, 26, 96)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 256)       2973952
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 256)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 6, 6, 384)         885120
# _________________________________________________________________
# activation_3 (Activation)    (None, 6, 6, 384)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 384)         1327488
# _________________________________________________________________
# activation_4 (Activation)    (None, 4, 4, 384)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 2, 2, 256)         884992
# _________________________________________________________________
# activation_5 (Activation)    (None, 2, 2, 256)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              1052672
# _________________________________________________________________
# activation_6 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# activation_7 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# activation_8 (Activation)    (None, 1000)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 4004
# _________________________________________________________________
# activation_9 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 28,018,252
# Trainable params: 28,018,252
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
opt = Adam(learning_rate=1e-5, beta_1=0.9, beta_2=0.999, amsgrad=False)

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer="adam",
              metrics=["accuracy"])

# %%
# train/ test
x_train, x_test, y_train, y_test = train_test_split(pad_ssm_lst, gest_lab, test_size=0.2, random_state=1)

# transform to numpy arrays
x_train = np.array(x_train).reshape(len(x_train), 63, 63, 1)
x_test = np.array(x_test).reshape(len(x_test), 63, 63, 1)
y_train = to_categorical(np.array(y_train))
y_test = to_categorical(np.array(y_test))

# %%
batch_size = int(len(gest_lab) / 2)
epochs = 200

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_data=(x_test, y_test),
                    shuffle=True)
# Out:
# WARNING:tensorflow:From /home/svois/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 460 samples, validate on 116 samples
# Epoch 1/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.4759 - accuracy: 0.3022 - val_loss: 1.3810 - val_accuracy: 0.3103
# Epoch 2/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3954 - accuracy: 0.2348 - val_loss: 1.3804 - val_accuracy: 0.3103
# Epoch 3/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3894 - accuracy: 0.2348 - val_loss: 1.3823 - val_accuracy: 0.3103
# Epoch 4/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3879 - accuracy: 0.2326 - val_loss: 1.3839 - val_accuracy: 0.3103
# Epoch 5/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3867 - accuracy: 0.2326 - val_loss: 1.3853 - val_accuracy: 0.3103
# Epoch 6/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3873 - accuracy: 0.2326 - val_loss: 1.3866 - val_accuracy: 0.2414
# Epoch 7/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3858 - accuracy: 0.2587 - val_loss: 1.3879 - val_accuracy: 0.2500
# Epoch 8/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3851 - accuracy: 0.2609 - val_loss: 1.3886 - val_accuracy: 0.2500
# Epoch 9/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3822 - accuracy: 0.2609 - val_loss: 1.3898 - val_accuracy: 0.2500
# Epoch 10/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3823 - accuracy: 0.2609 - val_loss: 1.3920 - val_accuracy: 0.1810
# Epoch 11/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3851 - accuracy: 0.2630 - val_loss: 1.3931 - val_accuracy: 0.1897
# Epoch 12/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3855 - accuracy: 0.2674 - val_loss: 1.3960 - val_accuracy: 0.1897
# Epoch 13/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3852 - accuracy: 0.2652 - val_loss: 1.3963 - val_accuracy: 0.1897
# Epoch 14/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3844 - accuracy: 0.2674 - val_loss: 1.3960 - val_accuracy: 0.1983
# Epoch 15/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3864 - accuracy: 0.2522 - val_loss: 1.3930 - val_accuracy: 0.2241
# Epoch 16/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3842 - accuracy: 0.2826 - val_loss: 1.3892 - val_accuracy: 0.2155
# Epoch 17/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.4038 - accuracy: 0.2826 - val_loss: 1.3902 - val_accuracy: 0.1897
# Epoch 18/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3820 - accuracy: 0.2804 - val_loss: 1.3927 - val_accuracy: 0.1897
# Epoch 19/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3873 - accuracy: 0.2630 - val_loss: 1.3924 - val_accuracy: 0.1897
# Epoch 20/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3865 - accuracy: 0.2609 - val_loss: 1.3923 - val_accuracy: 0.1897
# Epoch 21/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3870 - accuracy: 0.2674 - val_loss: 1.3922 - val_accuracy: 0.1897
# Epoch 22/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3870 - accuracy: 0.2761 - val_loss: 1.3918 - val_accuracy: 0.1897
# Epoch 23/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3871 - accuracy: 0.2674 - val_loss: 1.3917 - val_accuracy: 0.1897
# Epoch 24/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3860 - accuracy: 0.2652 - val_loss: 1.3922 - val_accuracy: 0.1897
# Epoch 25/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3861 - accuracy: 0.2630 - val_loss: 1.3928 - val_accuracy: 0.1897
# Epoch 26/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3868 - accuracy: 0.2630 - val_loss: 1.3931 - val_accuracy: 0.1897
# Epoch 27/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3861 - accuracy: 0.2652 - val_loss: 1.3932 - val_accuracy: 0.1897
# Epoch 28/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3850 - accuracy: 0.2652 - val_loss: 1.3934 - val_accuracy: 0.1897
# Epoch 29/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3844 - accuracy: 0.2652 - val_loss: 1.3937 - val_accuracy: 0.1897
# Epoch 30/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3852 - accuracy: 0.2652 - val_loss: 1.3942 - val_accuracy: 0.1897
# Epoch 31/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3854 - accuracy: 0.2652 - val_loss: 1.3945 - val_accuracy: 0.1897
# Epoch 32/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3859 - accuracy: 0.2652 - val_loss: 1.3948 - val_accuracy: 0.1897
# Epoch 33/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3858 - accuracy: 0.2652 - val_loss: 1.3948 - val_accuracy: 0.1897
# Epoch 34/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3849 - accuracy: 0.2674 - val_loss: 1.3949 - val_accuracy: 0.1897
# Epoch 35/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3845 - accuracy: 0.2717 - val_loss: 1.3953 - val_accuracy: 0.1897
# Epoch 36/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.
#  0.3017241358757019,
#  0.3017241358757019,
#  0.3362068831920624,
#  0.27586206793785095,
#  0.32758620381355286,
#  0.2931034564971924,
#  0.26724138855934143,
#  0.31896552443504333,
#  0.3103448152542114,
#  0.3017241358757019,
#  0.3017241358757019,
#  0.31896552443504333,
#  0.3362068831920624,
#  0.3448275923728943,
#  0.3103448152542114,
#  0.2931034564971924,
#  0.32758620381355286,
#  0.3017241358757019,
#  0.2931034564971924,
#  0.3103448152542114,
#  0.3362068831920624,
#  0.3017241358757019,
#  0.31896552443504333,
#  0.3017241358757019,
#  0.3534482717514038,
#  0.2844827473163605,
#  0.3448275923728943,
#  0.3017241358757019,
#  0.3534482717514038,
#  0.36206895112991333,
#  0.31896552443504333,
#  0.3103448152542114,
#  0.31896552443504333,
#  0.2844827473163605,
#  0.2586206793785095,
#  0.24137930572032928,
#  0.27586206793785095,
#  0.3017241358757019,
#  0.3103448152542114,
#  0.3362068831920624,
#  0.3448275923728943,
#  0.2931034564971924]

# %% [markdown]
# ---

# %%
#Instantiate an empty model_iso
model_iso = Sequential()

# 1st Convolutional Layer
model_iso.add(Conv2D(filters=96, input_shape=inp_shp, kernel_size=(11,11), strides=(1,1), padding="valid"))
model_iso.add(Activation("relu"))
# Max Pooling
model_iso.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding="valid"))

# 2nd Convolutional Layer
model_iso.add(Conv2D(filters=256, kernel_size=(11,11), strides=(1,1), padding="valid"))
model_iso.add(Activation("relu"))
# Max Pooling
model_iso.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding="valid"))

# 3rd Convolutional Layer
model_iso.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding="valid"))
model_iso.add(Activation("relu"))

# 4th Convolutional Layer
model_iso.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding="valid"))
model_iso.add(Activation("relu"))

# 5th Convolutional Layer
model_iso.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding="valid"))
model_iso.add(Activation("relu"))
# Max Pooling
model_iso.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding="valid"))

# Passing it to a Fully Connected layer
model_iso.add(Flatten())
# 1st Fully Connected Layer
model_iso.add(Dense(4096, input_shape=(224*224*3,)))
model_iso.add(Activation("relu"))
# Add Dropout to prevent overfitting
model_iso.add(Dropout(0.4))

# 2nd Fully Connected Layer
model_iso.add(Dense(4096))
model_iso.add(Activation("relu"))
# Add Dropout
model_iso.add(Dropout(0.4))

# 3rd Fully Connected Layer
model_iso.add(Dense(1000))
model_iso.add(Activation("relu"))
# Add Dropout
model_iso.add(Dropout(0.4))

# Output Layer
model_iso.add(Dense(4))
model_iso.add(Activation("softmax"))

model_iso.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 53, 53, 96)        11712
# _________________________________________________________________
# activation_10 (Activation)   (None, 53, 53, 96)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 26, 26, 96)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 256)       2973952
# _________________________________________________________________
# activation_11 (Activation)   (None, 16, 16, 256)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 6, 6, 384)         885120
# _________________________________________________________________
# activation_12 (Activation)   (None, 6, 6, 384)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 384)         1327488
# _________________________________________________________________
# activation_13 (Activation)   (None, 4, 4, 384)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 2, 2, 256)         884992
# _________________________________________________________________
# activation_14 (Activation)   (None, 2, 2, 256)         0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 4096)              1052672
# _________________________________________________________________
# activation_15 (Activation)   (None, 4096)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# activation_16 (Activation)   (None, 4096)              0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# activation_17 (Activation)   (None, 1000)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 4)                 4004
# _________________________________________________________________
# activation_18 (Activation)   (None, 4)                 0
# =================================================================
# Total params: 28,018,252
# Trainable params: 28,018,252
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
opt = Adam(learning_rate=1e-5, beta_1=0.9, beta_2=0.999, amsgrad=False)

model_iso.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer="adam",
                  metrics=["accuracy"])

# %%
# train/ test
x_train, x_test, y_train, y_test = train_test_split(pad_iso_lst, gest_lab, test_size=0.2, random_state=1)

# transform to numpy arrays
x_train = np.array(x_train).reshape(len(x_train), 63, 63, 1)
x_test = np.array(x_test).reshape(len(x_test), 63, 63, 1)
y_train = to_categorical(np.array(y_train))
y_test = to_categorical(np.array(y_test))

# %%
batch_size = int(len(gest_lab) / 2)
epochs = 200

history = model_iso.fit(x_train, y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        shuffle=True)
# Out:
# Train on 460 samples, validate on 116 samples
# Epoch 1/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.4295 - accuracy: 0.2413 - val_loss: 1.3838 - val_accuracy: 0.3103
# Epoch 2/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3916 - accuracy: 0.2348 - val_loss: 1.3845 - val_accuracy: 0.3103
# Epoch 3/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3876 - accuracy: 0.2348 - val_loss: 1.3862 - val_accuracy: 0.3103
# Epoch 4/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3877 - accuracy: 0.2283 - val_loss: 1.3872 - val_accuracy: 0.2241
# Epoch 5/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3865 - accuracy: 0.2457 - val_loss: 1.3878 - val_accuracy: 0.1983
# Epoch 6/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3864 - accuracy: 0.2739 - val_loss: 1.3890 - val_accuracy: 0.1897
# Epoch 7/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3851 - accuracy: 0.2717 - val_loss: 1.3852 - val_accuracy: 0.2931
# Epoch 8/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3892 - accuracy: 0.2739 - val_loss: 1.3910 - val_accuracy: 0.2586
# Epoch 9/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3817 - accuracy: 0.2630 - val_loss: 1.3961 - val_accuracy: 0.1810
# Epoch 10/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3846 - accuracy: 0.2630 - val_loss: 1.3986 - val_accuracy: 0.1897
# Epoch 11/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3864 - accuracy: 0.2696 - val_loss: 1.4001 - val_accuracy: 0.1897
# Epoch 12/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3870 - accuracy: 0.2652 - val_loss: 1.4010 - val_accuracy: 0.1897
# Epoch 13/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3858 - accuracy: 0.2630 - val_loss: 1.3984 - val_accuracy: 0.1897
# Epoch 14/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3867 - accuracy: 0.2674 - val_loss: 1.3965 - val_accuracy: 0.1897
# Epoch 15/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3849 - accuracy: 0.2717 - val_loss: 1.3951 - val_accuracy: 0.1897
# Epoch 16/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3848 - accuracy: 0.2826 - val_loss: 1.3942 - val_accuracy: 0.1897
# Epoch 17/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3851 - accuracy: 0.2696 - val_loss: 1.3937 - val_accuracy: 0.1897
# Epoch 18/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3850 - accuracy: 0.2783 - val_loss: 1.3937 - val_accuracy: 0.1897
# Epoch 19/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3867 - accuracy: 0.2370 - val_loss: 1.3945 - val_accuracy: 0.1897
# Epoch 20/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3865 - accuracy: 0.2674 - val_loss: 1.3962 - val_accuracy: 0.1897
# Epoch 21/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3881 - accuracy: 0.2630 - val_loss: 1.3976 - val_accuracy: 0.1897
# Epoch 22/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3875 - accuracy: 0.2652 - val_loss: 1.3970 - val_accuracy: 0.1897
# Epoch 23/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3873 - accuracy: 0.2630 - val_loss: 1.3957 - val_accuracy: 0.1897
# Epoch 24/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3866 - accuracy: 0.2674 - val_loss: 1.3949 - val_accuracy: 0.1897
# Epoch 25/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3861 - accuracy: 0.2543 - val_loss: 1.3946 - val_accuracy: 0.1897
# Epoch 26/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3852 - accuracy: 0.2652 - val_loss: 1.3934 - val_accuracy: 0.1897
# Epoch 27/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3845 - accuracy: 0.2587 - val_loss: 1.3923 - val_accuracy: 0.1897
# Epoch 28/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3856 - accuracy: 0.2543 - val_loss: 1.3920 - val_accuracy: 0.1897
# Epoch 29/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3860 - accuracy: 0.2630 - val_loss: 1.3928 - val_accuracy: 0.1897
# Epoch 30/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.
200
# 460/460 [==============================] - 9s 20ms/step - loss: 0.5176 - accuracy: 0.8370 - val_loss: 7.0265 - val_accuracy: 0.2759
# Epoch 185/200
# 460/460 [==============================] - 9s 20ms/step - loss: 0.7958 - accuracy: 0.7283 - val_loss: 6.1414 - val_accuracy: 0.2759
# Epoch 186/200
# 460/460 [==============================] - 9s 20ms/step - loss: 0.4834 - accuracy: 0.8435 - val_loss: 6.0504 - val_accuracy: 0.1983
# Epoch 187/200
# 460/460 [==============================] - 9s 20ms/step - loss: 0.4352 - accuracy: 0.8413 - val_loss: 6.0637 - val_accuracy: 0.2845
# Epoch 188/200
# 460/460 [==============================] - 9s 20ms/step - loss: 0.3958 - accuracy: 0.8609 - val_loss: 6.3140 - val_accuracy: 0.2931
# Epoch 189/200
# 460/460 [==============================] - 9s 20ms/step - loss: 0.3067 - accuracy: 0.8935 - val_loss: 6.0132 - val_accuracy: 0.3103
# Epoch 190/200
# 460/460 [==============================] - 9s 20ms/step - loss: 0.2628 - accuracy: 0.9022 - val_loss: 6.1394 - val_accuracy: 0.3448
# Epoch 191/200
# 460/460 [==============================] - 9s 20ms/step - loss: 0.2027 - accuracy: 0.9326 - val_loss: 6.9901 - val_accuracy: 0.3362
# Epoch 192/200
# 460/460 [==============================] - 9s 20ms/step - loss: 0.1953 - accuracy: 0.9326 - val_loss: 7.7020 - val_accuracy: 0.3448
# Epoch 193/200
# 460/460 [==============================] - 9s 20ms/step - loss: 0.1868 - accuracy: 0.9326 - val_loss: 8.1697 - val_accuracy: 0.2759
# Epoch 194/200
# 460/460 [==============================] - 9s 20ms/step - loss: 0.1672 - accuracy: 0.9391 - val_loss: 8.2416 - val_accuracy: 0.3103
# Epoch 195/200
# 460/460 [==============================] - 10s 21ms/step - loss: 0.1211 - accuracy: 0.9587 - val_loss: 8.4373 - val_accuracy: 0.2931
# Epoch 196/200
# 460/460 [==============================] - 10s 22ms/step - loss: 0.1283 - accuracy: 0.9565 - val_loss: 8.3259 - val_accuracy: 0.2672
# Epoch 197/200
# 460/460 [==============================] - 9s 20ms/step - loss: 0.1182 - accuracy: 0.9587 - val_loss: 8.0499 - val_accuracy: 0.2845
# Epoch 198/200
# 460/460 [==============================] - 9s 20ms/step - loss: 0.1055 - accuracy: 0.9674 - val_loss: 8.2682 - val_accuracy: 0.2931
# Epoch 199/200
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0964 - accuracy: 0.9652 - val_loss: 8.5342 - val_accuracy: 0.3017
# Epoch 200/200
# 460/460 [==============================] - 9s 20ms/step - loss: 0.0789 - accuracy: 0.9696 - val_loss: 8.8307 - val_accuracy: 0.2931

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
history.history["val_accuracy"]

# %% [markdown]
# 30% acc at 200 epochs

# %% [markdown]
# ---

# %%
#Instantiate an empty model_snf
model_snf = Sequential()

# 1st Convolutional Layer
model_snf.add(Conv2D(filters=96, input_shape=inp_shp, kernel_size=(11,11), strides=(1,1), padding="valid"))
model_snf.add(Activation("relu"))
# Max Pooling
model_snf.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding="valid"))

# 2nd Convolutional Layer
model_snf.add(Conv2D(filters=256, kernel_size=(11,11), strides=(1,1), padding="valid"))
model_snf.add(Activation("relu"))
# Max Pooling
model_snf.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding="valid"))

# 3rd Convolutional Layer
model_snf.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding="valid"))
model_snf.add(Activation("relu"))

# 4th Convolutional Layer
model_snf.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding="valid"))
model_snf.add(Activation("relu"))

# 5th Convolutional Layer
model_snf.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding="valid"))
model_snf.add(Activation("relu"))
# Max Pooling
model_snf.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding="valid"))

# Passing it to a Fully Connected layer
model_snf.add(Flatten())
# 1st Fully Connected Layer
model_snf.add(Dense(4096, input_shape=(224*224*3,)))
model_snf.add(Activation("relu"))
# Add Dropout to prevent overfitting
model_snf.add(Dropout(0.4))

# 2nd Fully Connected Layer
model_snf.add(Dense(4096))
model_snf.add(Activation("relu"))
# Add Dropout
model_snf.add(Dropout(0.4))

# 3rd Fully Connected Layer
model_snf.add(Dense(1000))
model_snf.add(Activation("relu"))
# Add Dropout
model_snf.add(Dropout(0.4))

# Output Layer
model_snf.add(Dense(4))
model_snf.add(Activation("softmax"))

model_snf.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 53, 53, 96)        11712
# _________________________________________________________________
# activation_19 (Activation)   (None, 53, 53, 96)        0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 26, 26, 96)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 16, 16, 256)       2973952
# _________________________________________________________________
# activation_20 (Activation)   (None, 16, 16, 256)       0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 6, 6, 384)         885120
# _________________________________________________________________
# activation_21 (Activation)   (None, 6, 6, 384)         0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 4, 4, 384)         1327488
# _________________________________________________________________
# activation_22 (Activation)   (None, 4, 4, 384)         0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 2, 2, 256)         884992
# _________________________________________________________________
# activation_23 (Activation)   (None, 2, 2, 256)         0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 4096)              1052672
# _________________________________________________________________
# activation_24 (Activation)   (None, 4096)              0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 4096)              16781312
# _________________________________________________________________
# activation_25 (Activation)   (None, 4096)              0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1000)              4097000
# _________________________________________________________________
# activation_26 (Activation)   (None, 1000)              0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 4)                 4004
# _________________________________________________________________
# activation_27 (Activation)   (None, 4)                 0
# =================================================================
# Total params: 28,018,252
# Trainable params: 28,018,252
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
opt = Adam(learning_rate=1e-5, beta_1=0.9, beta_2=0.999, amsgrad=False)

model_snf.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer="adam",
                  metrics=["accuracy"])

# %%
# train/ test
x_train, x_test, y_train, y_test = train_test_split(pad_snf_lst, gest_lab, test_size=0.2, random_state=1)

# transform to numpy arrays
x_train = np.array(x_train).reshape(len(x_train), 63, 63, 1)
x_test = np.array(x_test).reshape(len(x_test), 63, 63, 1)
y_train = to_categorical(np.array(y_train))
y_test = to_categorical(np.array(y_test))

# %%
batch_size = int(len(gest_lab) / 2)
epochs = 200

history = model_snf.fit(x_train, y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        shuffle=True)
# Out:
# Train on 460 samples, validate on 116 samples
# Epoch 1/200
# 460/460 [==============================] - 9s 20ms/step - loss: 3.7460 - accuracy: 0.2391 - val_loss: 1.3819 - val_accuracy: 0.2586
# Epoch 2/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.4099 - accuracy: 0.2587 - val_loss: 1.3804 - val_accuracy: 0.2414
# Epoch 3/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3915 - accuracy: 0.2391 - val_loss: 1.3814 - val_accuracy: 0.2414
# Epoch 4/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3901 - accuracy: 0.2457 - val_loss: 1.3833 - val_accuracy: 0.2414
# Epoch 5/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3879 - accuracy: 0.2500 - val_loss: 1.3845 - val_accuracy: 0.2414
# Epoch 6/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3878 - accuracy: 0.2522 - val_loss: 1.3854 - val_accuracy: 0.2414
# Epoch 7/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3871 - accuracy: 0.2543 - val_loss: 1.3862 - val_accuracy: 0.2414
# Epoch 8/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3864 - accuracy: 0.2565 - val_loss: 1.3867 - val_accuracy: 0.2414
# Epoch 9/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3863 - accuracy: 0.2522 - val_loss: 1.3872 - val_accuracy: 0.2414
# Epoch 10/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3864 - accuracy: 0.2522 - val_loss: 1.3874 - val_accuracy: 0.2414
# Epoch 11/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3860 - accuracy: 0.2543 - val_loss: 1.3880 - val_accuracy: 0.2414
# Epoch 12/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3856 - accuracy: 0.2587 - val_loss: 1.3890 - val_accuracy: 0.2241
# Epoch 13/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3853 - accuracy: 0.2761 - val_loss: 1.3898 - val_accuracy: 0.2241
# Epoch 14/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3856 - accuracy: 0.2239 - val_loss: 1.3904 - val_accuracy: 0.2241
# Epoch 15/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3846 - accuracy: 0.2543 - val_loss: 1.3912 - val_accuracy: 0.1983
# Epoch 16/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3841 - accuracy: 0.2609 - val_loss: 1.3917 - val_accuracy: 0.1983
# Epoch 17/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3837 - accuracy: 0.2543 - val_loss: 1.3923 - val_accuracy: 0.1897
# Epoch 18/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3825 - accuracy: 0.2717 - val_loss: 1.3929 - val_accuracy: 0.1983
# Epoch 19/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3963 - accuracy: 0.2478 - val_loss: 1.3937 - val_accuracy: 0.1897
# Epoch 20/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3837 - accuracy: 0.2761 - val_loss: 1.3946 - val_accuracy: 0.1897
# Epoch 21/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3845 - accuracy: 0.2696 - val_loss: 1.3958 - val_accuracy: 0.1897
# Epoch 22/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.3863 - accuracy: 0.2457 - val_loss: 1.3965 - val_accuracy: 0.1897
# Epoch 23/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3864 - accuracy: 0.2674 - val_loss: 1.3973 - val_accuracy: 0.1897
# Epoch 24/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3862 - accuracy: 0.2630 - val_loss: 1.3966 - val_accuracy: 0.1897
# Epoch 25/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3870 - accuracy: 0.2543 - val_loss: 1.3950 - val_accuracy: 0.1897
# Epoch 26/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.3866 - accuracy: 0.2587 - val_loss: 1.3945 - val_accuracy: 0.1897
# Epoch 27/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3858 - accuracy: 0.2630 - val_loss: 1.3930 - val_accuracy: 0.1897
# Epoch 28/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3852 - accuracy: 0.2652 - val_loss: 1.3927 - val_accuracy: 0.1897
# Epoch 29/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3863 - accuracy: 0.2630 - val_loss: 1.3922 - val_accuracy: 0.1897
# Epoch 30/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3863 - accuracy: 0.2457 - val_loss: 1.3915 - val_accuracy: 0.1897
# Epoch 31/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.3852 - accuracy: 0.2543 - val_loss: 1.3910 - val_accuracy: 0.1897
# Epoch 32/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3845 - accuracy: 0.2761 - val_loss: 1.3916 - val_accuracy: 0.1897
# Epoch 33/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3854 - accuracy: 0.2761 - val_loss: 1.3929 - val_accuracy: 0.1897
# Epoch 34/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3861 - accuracy: 0.2478 - val_loss: 1.3944 - val_accuracy: 0.1897
# Epoch 35/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3865 - accuracy: 0.2565 - val_loss: 1.3958 - val_accuracy: 0.1897
# Epoch 36/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3877 - accuracy: 0.2413 - val_loss: 1.3961 - val_accuracy: 0.1897
# Epoch 37/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3858 - accuracy: 0.2565 - val_loss: 1.3958 - val_accuracy: 0.1897
# Epoch 38/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.3846 - accuracy: 0.2783 - val_loss: 1.3961 - val_accuracy: 0.1897
# Epoch 39/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.3854 - accuracy: 0.2609 - val_loss: 1.3957 - val_accuracy: 0.1897
# Epoch 40/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3864 - accuracy: 0.2717 - val_loss: 1.3944 - val_accuracy: 0.1897
# Epoch 41/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3857 - accuracy: 0.2652 - val_loss: 1.3940 - val_accuracy: 0.1897
# Epoch 42/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3854 - accuracy: 0.2674 - val_loss: 1.3939 - val_accuracy: 0.1897
# Epoch 43/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3849 - accuracy: 0.2609 - val_loss: 1.3957 - val_accuracy: 0.1897
# Epoch 44/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3865 - accuracy: 0.2739 - val_loss: 1.3987 - val_accuracy: 0.1897
# Epoch 45/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3832 - accuracy: 0.2739 - val_loss: 1.4018 - val_accuracy: 0.1897
# Epoch 46/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.3848 - accuracy: 0.2826 - val_loss: 1.4041 - val_accuracy: 0.1897
# Epoch 47/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3838 - accuracy: 0.2804 - val_loss: 1.4033 - val_accuracy: 0.1638
# Epoch 48/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3819 - accuracy: 0.2717 - val_loss: 1.4039 - val_accuracy: 0.1638
# Epoch 49/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3780 - accuracy: 0.2739 - val_loss: 1.4104 - val_accuracy: 0.1638
# Epoch 50/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.
200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3366 - accuracy: 0.3239 - val_loss: 1.4665 - val_accuracy: 0.2414
# Epoch 82/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3314 - accuracy: 0.3457 - val_loss: 1.4479 - val_accuracy: 0.2845
# Epoch 83/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3094 - accuracy: 0.3630 - val_loss: 1.4288 - val_accuracy: 0.2845
# Epoch 84/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3407 - accuracy: 0.3217 - val_loss: 1.4328 - val_accuracy: 0.3534
# Epoch 85/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3474 - accuracy: 0.3391 - val_loss: 1.4387 - val_accuracy: 0.2845
# Epoch 86/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3147 - accuracy: 0.3587 - val_loss: 1.4282 - val_accuracy: 0.2672
# Epoch 87/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3122 - accuracy: 0.3500 - val_loss: 1.4602 - val_accuracy: 0.2241
# Epoch 88/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3295 - accuracy: 0.3500 - val_loss: 1.4400 - val_accuracy: 0.2500
# Epoch 89/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3332 - accuracy: 0.3630 - val_loss: 1.4276 - val_accuracy: 0.2586
# Epoch 90/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3306 - accuracy: 0.3326 - val_loss: 1.4433 - val_accuracy: 0.3190
# Epoch 91/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3212 - accuracy: 0.3348 - val_loss: 1.4666 - val_accuracy: 0.2845
# Epoch 92/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3186 - accuracy: 0.3478 - val_loss: 1.4331 - val_accuracy: 0.2845
# Epoch 93/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3138 - accuracy: 0.3739 - val_loss: 1.4321 - val_accuracy: 0.3017
# Epoch 94/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3099 - accuracy: 0.3674 - val_loss: 1.4668 - val_accuracy: 0.2845
# Epoch 95/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3068 - accuracy: 0.3826 - val_loss: 1.5002 - val_accuracy: 0.3017
# Epoch 96/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3142 - accuracy: 0.3457 - val_loss: 1.4348 - val_accuracy: 0.3103
# Epoch 97/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.3081 - accuracy: 0.3630 - val_loss: 1.4020 - val_accuracy: 0.3190
# Epoch 98/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3104 - accuracy: 0.3696 - val_loss: 1.4252 - val_accuracy: 0.3362
# Epoch 99/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.2991 - accuracy: 0.3543 - val_loss: 1.4629 - val_accuracy: 0.3017
# Epoch 100/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3099 - accuracy: 0.3630 - val_loss: 1.4888 - val_accuracy: 0.2931
# Epoch 101/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2935 - accuracy: 0.3696 - val_loss: 1.4912 - val_accuracy: 0.3017
# Epoch 102/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.2894 - accuracy: 0.3587 - val_loss: 1.4478 - val_accuracy: 0.2931
# Epoch 103/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2953 - accuracy: 0.3717 - val_loss: 1.4667 - val_accuracy: 0.3103
# Epoch 104/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.2981 - accuracy: 0.3804 - val_loss: 1.4954 - val_accuracy: 0.2845
# Epoch 105/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2981 - accuracy: 0.3652 - val_loss: 1.4612 - val_accuracy: 0.3103
# Epoch 106/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.3025 - accuracy: 0.3565 - val_loss: 1.4553 - val_accuracy: 0.3103
# Epoch 107/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2960 - accuracy: 0.3761 - val_loss: 1.4481 - val_accuracy: 0.3103
# Epoch 108/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2843 - accuracy: 0.3891 - val_loss: 1.4699 - val_accuracy: 0.3103
# Epoch 109/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.2989 - accuracy: 0.3609 - val_loss: 1.5118 - val_accuracy: 0.3362
# Epoch 110/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.2808 - accuracy: 0.3652 - val_loss: 1.4679 - val_accuracy: 0.3362
# Epoch 111/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.2753 - accuracy: 0.3587 - val_loss: 1.4901 - val_accuracy: 0.3017
# Epoch 112/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2784 - accuracy: 0.3804 - val_loss: 1.4754 - val_accuracy: 0.3103
# Epoch 113/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.2698 - accuracy: 0.3913 - val_loss: 1.4906 - val_accuracy: 0.3017
# Epoch 114/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2831 - accuracy: 0.3761 - val_loss: 1.5010 - val_accuracy: 0.2931
# Epoch 115/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.2709 - accuracy: 0.4196 - val_loss: 1.5236 - val_accuracy: 0.3103
# Epoch 116/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.2754 - accuracy: 0.3587 - val_loss: 1.5109 - val_accuracy: 0.2845
# Epoch 117/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.2733 - accuracy: 0.3848 - val_loss: 1.5349 - val_accuracy: 0.3190
# Epoch 118/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2626 - accuracy: 0.3913 - val_loss: 1.5799 - val_accuracy: 0.3103
# Epoch 119/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2813 - accuracy: 0.3913 - val_loss: 1.4680 - val_accuracy: 0.2845
# Epoch 120/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2648 - accuracy: 0.3913 - val_loss: 1.5161 - val_accuracy: 0.3103
# Epoch 121/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2590 - accuracy: 0.3913 - val_loss: 1.5077 - val_accuracy: 0.3103
# Epoch 122/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2783 - accuracy: 0.3870 - val_loss: 1.6814 - val_accuracy: 0.2759
# Epoch 123/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.3001 - accuracy: 0.3696 - val_loss: 1.5174 - val_accuracy: 0.3362
# Epoch 124/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2595 - accuracy: 0.3957 - val_loss: 1.4550 - val_accuracy: 0.3448
# Epoch 125/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2720 - accuracy: 0.3870 - val_loss: 1.4571 - val_accuracy: 0.3276
# Epoch 126/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.2615 - accuracy: 0.3870 - val_loss: 1.4574 - val_accuracy: 0.3103
# Epoch 127/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2626 - accuracy: 0.4152 - val_loss: 1.4808 - val_accuracy: 0.2845
# Epoch 128/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2465 - accuracy: 0.3848 - val_loss: 1.5532 - val_accuracy: 0.3362
# Epoch 129/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.2506 - accuracy: 0.3848 - val_loss: 1.4977 - val_accuracy: 0.3362
# Epoch 130/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2550 - accuracy: 0.3891 - val_loss: 1.5787 - val_accuracy: 0.3103
# Epoch 131/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2481 - accuracy: 0.3870 - val_loss: 1.5235 - val_accuracy: 0.3190
# Epoch 132/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2393 - accuracy: 0.3957 - val_loss: 1.5381 - val_accuracy: 0.3190
# Epoch 133/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2431 - accuracy: 0.3891 - val_loss: 1.5266 - val_accuracy: 0.3017
# Epoch 134/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2467 - accuracy: 0.4043 - val_loss: 1.5868 - val_accuracy: 0.2931
# Epoch 135/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2505 - accuracy: 0.4022 - val_loss: 1.5646 - val_accuracy: 0.2845
# Epoch 136/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2378 - accuracy: 0.4087 - val_loss: 1.5958 - val_accuracy: 0.2931
# Epoch 137/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2480 - accuracy: 0.4000 - val_loss: 1.5937 - val_accuracy: 0.3017
# Epoch 138/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2373 - accuracy: 0.3870 - val_loss: 1.6163 - val_accuracy: 0.3190
# Epoch 139/200
# 460/460 [==============================] - 10s 21ms/step - loss: 1.2442 - accuracy: 0.3717 - val_loss: 1.5863 - val_accuracy: 0.2845
# Epoch 140/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.2352 - accuracy: 0.4109 - val_loss: 1.5374 - val_accuracy: 0.3103
# Epoch 141/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2298 - accuracy: 0.4130 - val_loss: 1.5280 - val_accuracy: 0.3103
# Epoch 142/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2394 - accuracy: 0.3935 - val_loss: 1.5647 - val_accuracy: 0.2759
# Epoch 143/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.2239 - accuracy: 0.4196 - val_loss: 1.8513 - val_accuracy: 0.2759
# Epoch 144/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2641 - accuracy: 0.4000 - val_loss: 1.6111 - val_accuracy: 0.2500
# Epoch 145/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2528 - accuracy: 0.3870 - val_loss: 1.6848 - val_accuracy: 0.3103
# Epoch 146/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2890 - accuracy: 0.3891 - val_loss: 1.4927 - val_accuracy: 0.3103
# Epoch 147/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2643 - accuracy: 0.3891 - val_loss: 1.4993 - val_accuracy: 0.2931
# Epoch 148/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.2600 - accuracy: 0.4043 - val_loss: 1.6025 - val_accuracy: 0.2931
# Epoch 149/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2769 - accuracy: 0.3717 - val_loss: 1.5660 - val_accuracy: 0.2845
# Epoch 150/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2579 - accuracy: 0.3761 - val_loss: 1.5320 - val_accuracy: 0.2500
# Epoch 151/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2739 - accuracy: 0.3935 - val_loss: 1.5225 - val_accuracy: 0.2500
# Epoch 152/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2564 - accuracy: 0.3935 - val_loss: 1.5657 - val_accuracy: 0.2759
# Epoch 153/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2564 - accuracy: 0.4022 - val_loss: 1.5619 - val_accuracy: 0.2845
# Epoch 154/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.2321 - accuracy: 0.4348 - val_loss: 1.5412 - val_accuracy: 0.2672
# Epoch 155/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2518 - accuracy: 0.3957 - val_loss: 1.5675 - val_accuracy: 0.3017
# Epoch 156/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2270 - accuracy: 0.4174 - val_loss: 1.5990 - val_accuracy: 0.3362
# Epoch 157/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2265 - accuracy: 0.3957 - val_loss: 1.5796 - val_accuracy: 0.3017
# Epoch 158/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2226 - accuracy: 0.4087 - val_loss: 1.6280 - val_accuracy: 0.3448
# Epoch 159/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2138 - accuracy: 0.4130 - val_loss: 1.6561 - val_accuracy: 0.3017
# Epoch 160/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2121 - accuracy: 0.4043 - val_loss: 1.6207 - val_accuracy: 0.3017
# Epoch 161/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2249 - accuracy: 0.4217 - val_loss: 1.6879 - val_accuracy: 0.3362
# Epoch 162/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2182 - accuracy: 0.4065 - val_loss: 1.5837 - val_accuracy: 0.2759
# Epoch 163/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2947 - accuracy: 0.3739 - val_loss: 1.7701 - val_accuracy: 0.3276
# Epoch 164/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2568 - accuracy: 0.3696 - val_loss: 1.6367 - val_accuracy: 0.2931
# Epoch 165/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2200 - accuracy: 0.4326 - val_loss: 1.5099 - val_accuracy: 0.2672
# Epoch 166/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2554 - accuracy: 0.4065 - val_loss: 1.5553 - val_accuracy: 0.3190
# Epoch 167/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2183 - accuracy: 0.4130 - val_loss: 1.6090 - val_accuracy: 0.3103
# Epoch 168/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2230 - accuracy: 0.4217 - val_loss: 1.5652 - val_accuracy: 0.3017
# Epoch 169/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2101 - accuracy: 0.4261 - val_loss: 1.6446 - val_accuracy: 0.3017
# Epoch 170/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2075 - accuracy: 0.4087 - val_loss: 1.6246 - val_accuracy: 0.3190
# Epoch 171/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2018 - accuracy: 0.4022 - val_loss: 1.7447 - val_accuracy: 0.3362
# Epoch 172/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2105 - accuracy: 0.4065 - val_loss: 1.5945 - val_accuracy: 0.3448
# Epoch 173/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2199 - accuracy: 0.4130 - val_loss: 1.7492 - val_accuracy: 0.3103
# Epoch 174/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2245 - accuracy: 0.4065 - val_loss: 1.6523 - val_accuracy: 0.2931
# Epoch 175/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2081 - accuracy: 0.4152 - val_loss: 1.7185 - val_accuracy: 0.3276
# Epoch 176/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.1809 - accuracy: 0.4391 - val_loss: 1.7382 - val_accuracy: 0.3017
# Epoch 177/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.1739 - accuracy: 0.4391 - val_loss: 1.7002 - val_accuracy: 0.2931
# Epoch 178/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.1983 - accuracy: 0.4152 - val_loss: 1.7549 - val_accuracy: 0.3103
# Epoch 179/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.1869 - accuracy: 0.4391 - val_loss: 1.6433 - val_accuracy: 0.3362
# Epoch 180/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2016 - accuracy: 0.4087 - val_loss: 1.8201 - val_accuracy: 0.3017
# Epoch 181/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.1821 - accuracy: 0.4196 - val_loss: 1.6729 - val_accuracy: 0.3190
# Epoch 182/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.2016 - accuracy: 0.4391 - val_loss: 1.7914 - val_accuracy: 0.3017
# Epoch 183/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2044 - accuracy: 0.3913 - val_loss: 1.6215 - val_accuracy: 0.3534
# Epoch 184/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.1921 - accuracy: 0.4239 - val_loss: 1.7248 - val_accuracy: 0.2845
# Epoch 185/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.1816 - accuracy: 0.4348 - val_loss: 1.7755 - val_accuracy: 0.3448
# Epoch 186/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.1687 - accuracy: 0.4239 - val_loss: 1.8609 - val_accuracy: 0.3017
# Epoch 187/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.1896 - accuracy: 0.4109 - val_loss: 1.7610 - val_accuracy: 0.3534
# Epoch 188/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.1839 - accuracy: 0.4261 - val_loss: 1.7077 - val_accuracy: 0.3621
# Epoch 189/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.1779 - accuracy: 0.4326 - val_loss: 1.6830 - val_accuracy: 0.3190
# Epoch 190/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.1714 - accuracy: 0.4326 - val_loss: 1.7133 - val_accuracy: 0.3103
# Epoch 191/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.1580 - accuracy: 0.4522 - val_loss: 1.8534 - val_accuracy: 0.3190
# Epoch 192/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.1788 - accuracy: 0.4326 - val_loss: 1.7372 - val_accuracy: 0.2845
# Epoch 193/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2702 - accuracy: 0.4022 - val_loss: 1.9327 - val_accuracy: 0.2586
# Epoch 194/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2784 - accuracy: 0.3761 - val_loss: 1.6368 - val_accuracy: 0.2414
# Epoch 195/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2223 - accuracy: 0.4174 - val_loss: 1.6070 - val_accuracy: 0.2759
# Epoch 196/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2279 - accuracy: 0.3978 - val_loss: 1.6613 - val_accuracy: 0.3017
# Epoch 197/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2337 - accuracy: 0.4261 - val_loss: 1.7230 - val_accuracy: 0.3103
# Epoch 198/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.2191 - accuracy: 0.4304 - val_loss: 1.6737 - val_accuracy: 0.3362
# Epoch 199/200
# 460/460 [==============================] - 9s 19ms/step - loss: 1.2092 - accuracy: 0.4261 - val_loss: 1.7475 - val_accuracy: 0.3448
# Epoch 200/200
# 460/460 [==============================] - 9s 20ms/step - loss: 1.1986 - accuracy: 0.4043 - val_loss: 1.8538 - val_accuracy: 0.2931

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# Got into 32% around 200 epochs

# %%
history.history["val_accuracy"]
