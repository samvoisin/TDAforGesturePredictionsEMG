# %%
import numpy as np
from data_cube import DataCube

# %%
dc = DataCube(
        subjects="all",
        gestures=["1", "2", "3", "4"],
        channels=["2", "4", "5", "6", "8"],
        data_grp="parsed"
        )
dc.load_data()

dcs = DataCube(
        subjects="all",
        gestures=["1", "2", "3", "4"],
        data_grp="subsample"
        )
dcs.load_data()

# %%
print(dc.data_set["22"]["1_1_2"].shape)
dc.plot_gests("22", "1_1_2")
# Out:
# (1354, 7)

# %%
print(dcs.data_set["22"]["1_1_2"].shape)
dcs.plot_gests("22", "1_1_2", chans=[1,2,3,4,5])
# Out:
# (128, 7)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-83bf62258f13> in <module>
#       1 print(dcs.data_set["22"]["1_1_2"].shape)
# ----> 2 dcs.plot_gests("22", "1_1_2")
#
# ~/DukeUniv/MATH713_Topological_Data_Analysis/TDAforGesturePredictionsEMG/data_cube.py in plot_gests(self, subj, g, chans, save, path)
#     188                 ax[i, j].plot(
#     189                     time_ser,
# --> 190                     self.data_set[subj][g][:, clr+1],
#     191                     color=colors[clr]
#     192                     )
#
# IndexError: index 7 is out of bounds for axis 1 with size 7

# %%
print(dc.data_set["10"]["2_0_2"].shape)
dc.plot_gests("10", "2_0_2")
# Out:
# (1584, 7)

# %%
print(dcs.data_set["10"]["2_0_2"].shape)
dcs.plot_gests("10", "2_0_2", chans=[1,2,3,4,5])
# Out:
# (256, 7)

# %%
print(dc.data_set["01"]["4_1_1"].shape)
dc.plot_gests("01", "4_1_1")
# Out:
# (1706, 7)

# %%
print(dcs.data_set["01"]["4_1_1"].shape)
dcs.plot_gests("01", "4_1_1", chans=[1,2,3,4,5])
# Out:
# (256, 7)

# %%
print(dc.data_set["36"]["3_1_2"].shape)
dc.plot_gests("36", "3_1_2")
# Out:
# (1391, 7)

# %%
print(dcs.data_set["36"]["3_1_2"].shape)
dcs.plot_gests("36", "3_1_2", chans=[1,2,3,4,5])
# Out:
# (256, 7)

# %%
dcs.data_set["36"]["3_1_2"][1, :]
# Out:
# array([ 1.8e+01, -1.6e-04, -1.0e-05,  0.0e+00,  1.0e-05, -3.0e-05,
#         3.0e+00])

# %%
dcs.data_set["36"]["3_1_2"][-1, :]
# Out:
# array([0., 0., 0., 0., 0., 0., 0.])
