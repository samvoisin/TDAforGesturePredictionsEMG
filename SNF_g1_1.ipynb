# %%
import numpy as np
from numpy import linalg as la
import matplotlib.pyplot as plt
from scipy.interpolate import griddata

from data_cube import DataCube
from ssm import SSM
from snf import SNF

# %%
dc = DataCube(
    subjects=["01"],
    gestures=["1", "2", "3", "4"],
    channels=["2", "4", "5", "6", "8"],
    data_grp="parsed"
)
dc.load_data()
dc.rms_smooth(300, 20)
dc.get_max_obs(smooth=True)

# %%
snf_tst = SNF(dc.data_set_smooth["01"]["1_1_1"][:, :6])
snf_tst.normalize_modalities()

# %%
snf_tst.calc_SSM()

# %%
# channel 2
snf_tst.plot_SSM(0)

# %%
# channel 4
snf_tst.plot_SSM(1)

# %%
# channel 5
snf_tst.plot_SSM(2)

# %%
# channel 6
snf_tst.plot_SSM(3)

# %%
# channel 8
snf_tst.plot_SSM(4)

# %%
snf_tst.calc_sim_matrix()

# %%
# channel 2
snf_tst.plot_SSM(0)

# %%
# channel 4
snf_tst.plot_SSM(1)

# %%
# channel 5
snf_tst.plot_SSM(2)

# %%
# channel 6
snf_tst.plot_SSM(3)

# %%
# channel 8
snf_tst.plot_SSM(4)

# %%
snf_tst.calc_transition_matrix()
snf_tst.calc_similarity_graph(0.1)

# %%
snf_tst.network_fusion()

# %%
snf_tst.plot_template(0, fused=False)

# %%
snf_tst.plot_template(1, fused=False)

# %%
snf_tst.plot_template(2, fused=False)

# %%
snf_tst.plot_template(3, fused=False)

# %%
snf_tst.plot_template(4, fused=False)

# %%
snf_tst.plot_template()

# %%
tidx = snf_tst.tidx
mods = snf_tst.mods

# %%
plt.plot(tidx, mods[:,0])
plt.plot(tidx, mods[:,1])
plt.plot(tidx, mods[:,2])
plt.plot(tidx, mods[:,3])
plt.plot(tidx, mods[:,4])
plt.show()

# %%
plt.scatter(tidx, mods[:, 1])

# %%
plt.scatter(tidx[30:50], mods[30:50, 1])

# %%
mods[30:50,1]
# Out:
# array([ 1.85817297,  2.20934657,  2.00334317,  1.9975702 ,  1.53534974,
#         0.77758003,  0.40123914, -0.20986853, -0.35973237, -0.32742243,
#        -0.71139148, -1.69710005, -1.55214214, -1.23379743, -0.6222352 ,
#        -0.98417157, -1.39350616, -0.59639117, -0.16747149, -0.16394669])
