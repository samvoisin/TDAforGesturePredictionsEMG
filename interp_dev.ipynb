# %%
import numpy as np
from numpy import linalg as la
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale

from data_cube import DataCube

# %%
from scipy import interpolate

# %%
dc = DataCube(
    subjects=["10","20"],
    gestures=["3", "4", "5", "6"],
    channels=["2", "4", "6", "8"],
    data_grp="parsed"
)
dc.load_data()
dc.rms_smooth(100, 50)
dc.normalize_modalities(smooth=True)

# %% [markdown]
# ---

# %%
dc.interpolate_modalities()

# %%
sbj = "10"
g = "3_1_1"
plt.plot(dc.data_set_interp[sbj][g][:,0], dc.data_set_interp[sbj][g][:,1],"-")
plt.show()

# %%
plt.plot(dc.data_set_interp[sbj][g][:,0], dc.data_set_interp[sbj][g][:,2],"-")
plt.show()

# %%
plt.plot(dc.data_set_interp[sbj][g][:,0], dc.data_set_interp[sbj][g][:,3],"-")
plt.show()

# %%
plt.plot(dc.data_set_interp[sbj][g][:,0], dc.data_set_interp[sbj][g][:,4],"-")
plt.show()
